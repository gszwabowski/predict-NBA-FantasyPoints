# %% [markdown]
# ## Get This Season's Data

# %%
# imports
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
# columns for dataframe
colnames = ['Player',
            'Date',
            'Age',
            'Team',
            'at',
            'Opp',
            'Result',
            'GS',
            'MP',
            'FG',
            'FGA',
            'FG%',
            '2P',
            '2PA',
            '2P%',
            '3P',
            '3PA',
            '3P%',
            'FT',
            'FTA',
            'FT%',
            'TS%',
            'ORB',
            'DRB',
            'TRB',
            'AST',
            'STL',
            'BLK',
            'TOV',
            'PF',
            'PTS',
            'GmSc',
            'BPM',
            'Pos.',
           ]

# %%
len(colnames)
# Out:
# 34

# %%
import requests

# %%
# simulate login request and get StatHead data for recent games

frames = []
session_requests = requests.session()

cookies = {
    'srcssfull': 'yes',
    '_gid': 'GA1.2.1144777454.1666371428',
    '__qca': 'P0-1983082131-1666371428064',
    '_gcl_au': '1.1.804656925.1666371428',
    '__hstc': '205977932.9b3571e9488b91d911b7f8bae1cc2e1a.1666371428458.1666371428458.1666371428458.1',
    'hubspotutk': '9b3571e9488b91d911b7f8bae1cc2e1a',
    '__hssrc': '1',
    'csrf_token': 'b595055404b98dd2e1087410296698f8',
    '_ga': 'GA1.2.979883835.1666371428',
    '_gat_gtag_UA_1890630_24': '1',
    '_gat_gtag_UA_1890630_9': '1',
    '__hssc': '205977932.53.1666371428459',
    '_ga_2M1H4N076C': 'GS1.1.1666371428.1.1.1666375570.0.0.0',
}

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Language': 'en-US,en;q=0.9',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    # Requests sorts cookies= alphabetically
    # 'Cookie': 'srcssfull=yes; _gid=GA1.2.1144777454.1666371428; __qca=P0-1983082131-1666371428064; _gcl_au=1.1.804656925.1666371428; __hstc=205977932.9b3571e9488b91d911b7f8bae1cc2e1a.1666371428458.1666371428458.1666371428458.1; hubspotutk=9b3571e9488b91d911b7f8bae1cc2e1a; __hssrc=1; csrf_token=b595055404b98dd2e1087410296698f8; _ga=GA1.2.979883835.1666371428; _gat_gtag_UA_1890630_24=1; _gat_gtag_UA_1890630_9=1; __hssc=205977932.53.1666371428459; _ga_2M1H4N076C=GS1.1.1666371428.1.1.1666375570.0.0.0',
    'Origin': 'https://stathead.com',
    'Referer': 'https://stathead.com/users/login.cgi',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Chromium";v="106", "Google Chrome";v="106", "Not;A=Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

data = {
    'username': null,
    'password': null,
    'remember': '1',
    'token': '0',
    'csrf_token': 'ecdc775b8d3ed1c174b44d09b4a14cb2',
}

response = session_requests.post('https://stathead.com/users/login.cgi', cookies=cookies, headers=headers, data=data)

df_number = 0
for offset in range(0, 15600, 200):
    df_number += 1
    print('getting dataframe', str(df_number), 'of', str(15600/200))
    request_url = 'https://stathead.com/basketball/player-game-finder.cgi?request=1&comp_type=reg&order_by=date&match=player_game&season_start=1&year_max=2023&season_end=-1&order_by_asc=0&comp_id=NBA&year_min=2023&offset=' + str(offset)
    r = session_requests.get(request_url, headers = headers)
    soup = BeautifulSoup(r.content, 'lxml')
    rows = soup.findAll('tr')[1:]

    l = []
    for tr in rows:
        td = tr.find_all('td')
        row = [tr.text for tr in td]
        l.append(row)

    df = pd.DataFrame(l, columns=colnames)
    frames.append(df)
# Out:
# getting dataframe 1 of 78.0
# getting dataframe 2 of 78.0
# getting dataframe 3 of 78.0
# getting dataframe 4 of 78.0
# getting dataframe 5 of 78.0
# getting dataframe 6 of 78.0
# getting dataframe 7 of 78.0
# getting dataframe 8 of 78.0
# getting dataframe 9 of 78.0
# getting dataframe 10 of 78.0
# getting dataframe 11 of 78.0
# getting dataframe 12 of 78.0
# getting dataframe 13 of 78.0
# getting dataframe 14 of 78.0
# getting dataframe 15 of 78.0
# getting dataframe 16 of 78.0
# getting dataframe 17 of 78.0
# getting dataframe 18 of 78.0
# getting dataframe 19 of 78.0
# getting dataframe 20 of 78.0
# getting dataframe 21 of 78.0
# getting dataframe 22 of 78.0
# getting dataframe 23 of 78.0
# getting dataframe 24 of 78.0
# getting dataframe 25 of 78.0
# getting dataframe 26 of 78.0
# getting dataframe 27 of 78.0
# getting dataframe 28 of 78.0
# getting dataframe 29 of 78.0
# getting dataframe 30 of 78.0
# getting dataframe 31 of 78.0
# getting dataframe 32 of 78.0
# getting dataframe 33 of 78.0
# getting dataframe 34 of 78.0
# getting dataframe 35 of 78.0
# getting dataframe 36 of 78.0
# getting dataframe 37 of 78.0
# getting dataframe 38 of 78.0
# getting dataframe 39 of 78.0
# getting dataframe 40 of 78.0
# getting dataframe 41 of 78.0
# getting dataframe 42 of 78.0
# getting dataframe 43 of 78.0
# getting dataframe 44 of 78.0
# getting dataframe 45 of 78.0
# getting dataframe 46 of 78.0
# getting dataframe 47 of 78.0
# getting dataframe 48 of 78.0
# getting dataframe 49 of 78.0
# getting dataframe 50 of 78.0
# getting dataframe 51 of 78.0
# getting dataframe 52 of 78.0
# getting dataframe 53 of 78.0
# getting dataframe 54 of 78.0
# getting dataframe 55 of 78.0
# getting dataframe 56 of 78.0
# getting dataframe 57 of 78.0
# getting dataframe 58 of 78.0
# getting dataframe 59 of 78.0
# getting dataframe 60 of 78.0
# getting dataframe 61 of 78.0
# getting dataframe 62 of 78.0
# getting dataframe 63 of 78.0
# getting dataframe 64 of 78.0
# getting dataframe 65 of 78.0
# getting dataframe 66 of 78.0
# getting dataframe 67 of 78.0
# getting dataframe 68 of 78.0
# getting dataframe 69 of 78.0
# getting dataframe 70 of 78.0
# getting dataframe 71 of 78.0
# getting dataframe 72 of 78.0
# getting dataframe 73 of 78.0
# getting dataframe 74 of 78.0
# getting dataframe 75 of 78.0
# getting dataframe 76 of 78.0
# getting dataframe 77 of 78.0
# getting dataframe 78 of 78.0

# %%
working_directory = 'D:/machine_learning/DFS/NBA/NBA_moredata'
import os
os.chdir(working_directory)

# concatenate StatHead pages into a single dataframe and write to file
df_current = pd.concat(frames, axis=0)

df_current.reset_index(drop=True, inplace=True)

display(df_current)

df_current.to_csv('player_stats_YTD.csv')
# Out:
#                          Player        Date     Age Team at  Opp     Result  \
# 0              Precious Achiuwa  2023-01-25  23-128  TOR  @  SAC   W 113-95
# 1                  Ochai Agbaji  2023-01-25  22-280  UTA  @  POR  L 124-134
# 2                  Santi Aldama  2023-01-25  22-015  MEM  @  GSW  L 120-122
# 3      Nickeil Alexander-Walker  2023-01-25  24-145  UTA  @  POR  L 124-134
# 4                 Grayson Allen  2023-01-25  27-109  MIL     DEN   W 107-99
# ...                         ...         ...     ...  ... ..  ...        ...
# 15444         Russell Westbrook  2022-10-18  33-340  LAL  @  GSW  L 109-123
# 15445             Derrick White  2022-10-18  28-108  BOS     PHI  W 126-117
# 15446            Andrew Wiggins  2022-10-18  27-237  GSW     LAL  W 123-109
# 15447            Grant Williams  2022-10-18  23-322  BOS     PHI  W 126-117
# 15448             James Wiseman  2022-10-18  21-201  GSW     LAL  W 123-109
#
#       GS  MP FG  ... TRB AST STL BLK TOV PF PTS  GmSc   BPM Pos.
# 0      0  28  9  ...   5   0   0   0   3  3  19  11.9  -2.3    F
# 1      0  12  0  ...   2   2   0   0   0  0   0   2.1  -2.5    G
# 2      0  21  5  ...   3   0   0   0   0  2  13  11.6   9.0    F
# 3      0   1  0  ...   0   2   0   0   0  0   0   1.4  65.5    G
# 4      1  28  2  ...   5   1   3   0   0  1   7   8.0   2.4    G
# ...   ..  .. ..  ...  ..  ..  ..  ..  .. ..  ..   ...   ...  ...
# 15444  1  31  7  ...  11   3   1   0   4  1  19  15.4   0.7    G
# 15445  1  24  1  ...   3   4   1   0   1  2   2   3.2  -3.0    G
# 15446  1  29  8  ...   6   4   1   1   1  5  20  17.1   9.3  F-G
# 15447  0  24  5  ...   1   1   0   0   0  3  15  12.9  10.4    F
# 15448  0  17  4  ...   7   0   0   1   0  2   8   6.2  -2.1    C
#
# [15449 rows x 34 columns]
