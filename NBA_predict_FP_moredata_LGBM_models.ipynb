# %% [markdown]
# # PART 3.1: LGBM Model Development

# %% [markdown]
# ## Guard Model

# %%
"""
"""

import os
import joblib
import numpy as np
import pandas as pd
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

from sklearn.feature_selection import RFE


working_directory = 'D:/machine_learning/DFS/NBA/NBA_moredata'
os.chdir(working_directory)
data_dir = 'Data/'
etl_dir = 'Data/ETL/'

player_stats = pd.read_csv(data_dir + 'player_stats_all.csv', index_col = 0)
g_vs = pd.read_csv(etl_dir + 'g_stats.csv', index_col = 0)

g_vs = g_vs.rename(columns={'Opp':'Defense', 'Team_x' : 'Team'})

print(g_vs.columns.tolist())

#Grab Only Necessary Columns & Filter Only To G Data
g_act_stats = player_stats[(player_stats['Pos.']=='G') | (player_stats['Pos.']=='F-G') | (player_stats['Pos.']=='G-F')].copy().reset_index(drop=True)

g_act_stats = g_act_stats.fillna(0)

g_act_stats.drop(list(set(g_act_stats.columns) - set(g_vs)), axis = 1, inplace = True)

#Calculate The Draftkings Points for each player on each date
g_act_stats['Act_G_DKPts'] = (g_act_stats['3P'] * 1 + g_act_stats['AST'] * 1.5 +\
                           g_act_stats['BLK'] * 3 + g_act_stats['FG'] * 2 +\
                           g_act_stats['FT'] * 1 + g_act_stats['TRB'] * 1.2 +\
                           g_act_stats['STL'] * 3 + g_act_stats['TOV'] * -1)

#G DK PTS Rank For The Given Season & Date Pair
g_act_stats['Act_G_DKPtsRank'] = g_act_stats.groupby(['Season','Date'])['Act_G_DKPts'].rank(method='min', ascending = False)

#Columns We Want To Add To Dataset
keep_cols = ['Season','Date','Player','Act_G_DKPtsRank','Act_G_DKPts']

#Append Actual DK Pts Rank & DK Pts
g_vs_act = pd.merge(g_vs, g_act_stats[keep_cols], how = 'left', on = ['Season','Date','Player'])
g_vs_act = g_vs_act[g_vs_act['Act_G_DKPts']>0].reset_index(drop=True)

#Make sure we have no duplicated columns or infinity errors
g_vs_act = g_vs_act.loc[:,~g_vs_act.columns.duplicated()]
g_vs_act = g_vs_act.replace([np.inf, -np.inf], np.nan)
g_vs_act.to_csv(etl_dir + 'g_v_def_stats.csv')

#Columns We Can't Include In Our Features Datasets
dcols = ['Age',
         'at',
         'Result',
         'GS',
         'FG',
         'FGA',
         'FG%',
         '2P',
         '2PA',
         '2P%',
         '3P',
         '3PA',
         '3P%',
         'FT',
         'FTA',
         'FT%',
         'TS%',
         'ORB',
         'DRB',
         'TRB',
         'AST',
         'STL',
         'BLK',
         'TOV',
         'PF',
         'PTS',
         'GmSc',
         'BPM',
         'Pos.',
         'Month',
         'Year',
         'Team_y',
         'Act_G_DKPts',
         'EFF',
         'MP'
]


more_dcols = ['Season', 'Date', 'Team', 'Defense', 'Player', 'Act_G_DKPtsRank']

# g_vs_act.drop_duplicates(subset=['Player', 'Date'], keep='first', inplace = True, ignore_index = True)

X = g_vs_act.drop(dcols, axis = 1)
Y = g_vs_act['Act_G_DKPts']

from sklearn.model_selection import train_test_split

#Create Training and Testing DataSets
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.25, random_state=42)

X_train.reset_index(inplace = True, drop=True)
X_test.reset_index(inplace = True, drop=True)
Y_train.reset_index(inplace = True, drop=True)
Y_test.reset_index(inplace = True, drop=True)

print('Training set size:', len(X_train))
print('Testing set size:', len(X_test))

pred_df = pd.concat([X_test, Y_test], axis = 1)

X_train.drop(more_dcols, axis = 1, inplace = True)
X_test.drop(more_dcols, axis = 1, inplace = True)
# Out:
# ['Player', 'Date', 'Age', 'Team', 'at', 'Defense', 'Result', 'GS', 'MP', 'FG', 'FGA', 'FG%', '2P', '2PA', '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'TS%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', 'BPM', 'Pos.', 'EFF', 'Month', 'Year', 'Season', 'MP3', 'MP_pg3', 'FG3', 'FG_pg3', 'FGA3', 'FGA_pg3', 'FG%_pg3', '2P3', '2P_pg3', '2PA3', '2PA_pg3', '2P%_pg3', '3P3', '3P_pg3', '3PA3', '3PA_pg3', '3P%_pg3', 'FT3', 'FT_pg3', 'FTA3', 'FTA_pg3', 'FT%3', 'FT%_pg3', 'TS%_pg3', 'ORB3', 'ORB_pg3', 'DRB3', 'DRB_pg3', 'TRB3', 'TRB_pg3', 'AST3', 'AST_pg3', 'STL3', 'STL_pg3', 'BLK3', 'BLK_pg3', 'TOV3', 'TOV_pg3', 'PF3', 'PF_pg3', 'PTS3', 'PTS_pg3', 'GmSc3', 'GmSc_pg3', 'BPM_pg3', 'EFF3', 'EFF_pg3', 'g_MP3Rank3', 'g_FG3Rank3', 'g_FGARank3', 'g_FG%Rank3', 'g_2PRank3', 'g_2PARank3', 'g_2P%Rank3', 'g_3PRank3', 'g_3PARank3', 'g_3P%Rank3', 'g_FTRank3', 'g_FTARank3', 'g_FT%Rank3', 'g_TS%Rank3', 'g_ORBRank3', 'g_DRBRank3', 'g_TRBRank3', 'g_ASTRank3', 'g_STLRank3', 'g_BLKRank3', 'g_TOVRank3', 'g_PFRank3', 'g_PTSRank3', 'g_GMScRank3', 'g_BPMRank3', 'g_EFFRank3', 'g_DKPts3', 'g_DKPtsRank3', 'MinutesPlayed', 'MinutesPlayed_pg', 'FieldGoals', 'FieldGoals_pg', 'FieldGoalAttempts', 'FieldGoalAttempts_pg', 'FieldGoalPercentage_pg', 'TwoPointers', 'TwoPointers_pg', 'TwoPointAttempts', 'TwoPointAttempts_pg', 'TwoPointPercentage_pg', 'ThreePointers', 'ThreePointers_pg', 'ThreePointAttempts', 'ThreePointAttempts_pg', 'ThreePointPercentage_pg', 'FreeThrows', 'FreeThrows_pg', 'FreeThrowAttempts', 'FreeThrowAttempts_pg', 'FreeThrowPercentage_pg', 'TrueShootingPercentage_pg', 'OffensiveRebounds', 'OffensiveRebounds_pg', 'DefensiveRebounds', 'DefensiveRebounds_pg', 'TotalRebounds', 'TotalRebounds_pg', 'Assists', 'Assists_pg', 'Steals', 'Steals_pg', 'Blocks', 'Blocks_pg', 'Turnovers', 'Turnovers_pg', 'PersonalFouls', 'PersonalFouls_pg', 'Points', 'Points_pg', 'GameScore_pg', 'BoxPlusMinus_pg', 'Efficiency_pg', 'g_DKPts_szn', 'g_DKPtsRank_szn', 'def_MP3', 'def_MP_pg3', 'def_FG3', 'def_FG_pg3', 'def_FGA3', 'def_FGA_pg3', 'def_FG%_pg3', 'def_2P3', 'def_2P_pg3', 'def_2PA3', 'def_2PA_pg3', 'def_2P%_pg3', 'def_3P3', 'def_3P_pg3', 'def_3PA3', 'def_3PA_pg3', 'def_3P%_pg3', 'def_FT3', 'def_FT_pg3', 'def_FTA3', 'def_FTA_pg3', 'def_FT%_pg3', 'def_TS%_pg3', 'def_ORB3', 'def_ORB_pg3', 'def_DRB3', 'def_DRB_pg3', 'def_TRB3', 'def_TRB_pg3', 'def_AST3', 'def_AST_pg3', 'def_STL3', 'def_STL_pg3', 'def_BLK3', 'def_BLK_pg3', 'def_TOV3', 'def_TOV_pg3', 'def_PF3', 'def_PF_pg3', 'def_PTS3', 'def_PTS_pg3', 'def_GmSc3', 'def_GmSc_pg3', 'def_BPM_pg3', 'def_EFF3', 'def_EFF_pg3', 'def_g_MP3Rank3', 'def_g_FG3Rank3', 'def_g_FGARank3', 'def_g_FG%Rank3', 'def_g_2PRank3', 'def_g_2PARank3', 'def_g_2P%Rank3', 'def_g_3PRank3', 'def_g_3PARank3', 'def_g_3P%Rank3', 'def_g_FTRank3', 'def_g_FTARank3', 'def_g_FT%Rank3', 'def_g_TS%Rank3', 'def_g_ORBRank3', 'def_g_DRBRank3', 'def_g_TRBRank3', 'def_g_ASTRank3', 'def_g_STLRank3', 'def_g_BLKRank3', 'def_g_TOVRank3', 'def_g_PFRank3', 'def_g_PTSRank3', 'def_g_GMScRank3', 'def_g_BPMRank3', 'def_g_EFFRank3', 'def_g_DKPts3', 'def_g_DKPtsRank3', 'def_MinutesPlayed', 'def_MinutesPlayed_pg', 'def_FieldGoals', 'def_FieldGoals_pg', 'def_FieldGoalAttempts', 'def_FieldGoalAttempts_pg', 'def_FieldGoalPercentage_pg', 'def_TwoPointers', 'def_TwoPointers_pg', 'def_TwoPointAttempts', 'def_TwoPointAttempts_pg', 'def_TwoPointPercentage_pg', 'def_ThreePointers', 'def_ThreePointers_pg', 'def_ThreePointAttempts', 'def_ThreePointAttempts_pg', 'def_ThreePointPercentage_pg', 'def_FreeThrows', 'def_FreeThrows_pg', 'def_FreeThrowAttempts', 'def_FreeThrowAttempts_pg', 'def_FreeThrowPercentage_pg', 'def_TrueShootingPercentage_pg', 'def_OffensiveRebounds', 'def_OffensiveRebounds_pg', 'def_DefensiveRebounds', 'def_DefensiveRebounds_pg', 'def_TotalRebounds', 'def_TotalRebounds_pg', 'def_Assists', 'def_Assists_pg', 'def_Steals', 'def_Steals_pg', 'def_Blocks', 'def_Blocks_pg', 'def_Turnovers', 'def_Turnovers_pg', 'def_PersonalFouls', 'def_PersonalFouls_pg', 'def_Point ...
# Training set size: 120523
# Testing set size: 40175
# C:\Users\Greg\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# dump non-scaled train df for external scaling to work
filename = 'scalers/g_X_train.pkl'
joblib.dump(X_train, filename)

# Scaling
from sklearn.preprocessing import StandardScaler
g_scaler = StandardScaler().fit(X_train)
X_train = pd.DataFrame(g_scaler.transform(X_train), columns = X_train.columns)
X_test = pd.DataFrame(g_scaler.transform(X_test), columns = X_test.columns)
filename = 'scalers/g_scaler.pkl'
joblib.dump(g_scaler, filename)

print('\nNum Possible Features:',len(X_train.columns.tolist()))
# Out:
# Num Possible Features: 241

# %%
# hyperparameter tuning function
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

def hyperparameter_tuning(feat_set):
    # define model for param tuning
    model = LGBMRegressor()

    # define param grid
    param_grid = {
        'random_state' : [1],
        'n_jobs' : [-1],
        'n_estimators' : [1000],
        'learning_rate': [0.1],
        'num_leaves': [62, 93, 127],
        'max_depth' :[-1, 20, 40],
        'min_child_samples' : [20, 80],
        'max_bin' : [63],
        'device' : ['gpu']
    }

    gsearch = GridSearchCV(model, param_grid, verbose = 10, scoring = 'neg_mean_absolute_error') 

    lgb_model = gsearch.fit(X_train[feat_set], Y_train)
    print('best params')
    print(gsearch.best_params_, gsearch.best_score_)
    preds_lgb_model = lgb_model.predict(X_test[feat_set])
    mae_lgb = mean_absolute_error(Y_test, preds_lgb_model)
    print(" MAE: %f" % (mae_lgb ))
    return lgb_model.best_params_

# %%
# hyperparameter tuning for all features
best_params_all = hyperparameter_tuning(X_train.columns.tolist())

""" MODEL SELECTION (ALL FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_all)
"""                 """

#print possible features
print('possible features:', X_train.columns.tolist(), '\n')

# Fit model, make predictions with all features
model.fit(X_train, Y_train)

preds_all = model.predict(X_test)

pdf = pred_df[['Season','Date','Team','Defense','Player','Act_G_DKPtsRank','Act_G_DKPts']].copy()
pdf['Pred_G_DKPts_all'] = preds_all
pdf['PredictedallRank'] = pdf.groupby(['Season','Date'])['Pred_G_DKPts_all'].rank(method='min', ascending = False)
temp_df_all = pdf[pdf['PredictedallRank']<=5]

# save the initial model to disk
filename = 'models/LGBM_models/G_model_allfeats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.520 total time=  14.8s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.570 total time=  14.8s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.553 total time=  14.7s
# [CV 4/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.568 total time=  14.6s
# [CV 5/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.592 total time=  15.0s
# [CV 1/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.290 total time=  21.5s
# [CV 2/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.309 total time=  21.1s
# [CV 3/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.285 total time=  20.7s
# [CV 4/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.320 total time=  19.8s
# [CV 5/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.358 total time=  20.3s
# [CV 1/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.103 total time=  28.2s
# [CV 2/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.117 total time=  27.5s
# [CV 3/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.088 total time=  28.1s
# [CV 4/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.100 total time=  27.3s
# [CV 5/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.159 total time=  28.5s
# [CV 1/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.578 total time=  13.8s
# [CV 2/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.590 total time=  13.8s
# [CV 3/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.602 total time=  13.9s
# [CV 4/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.618 total time=  14.1s
# [CV 5/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.633 total time=  14.0s
# [CV 1/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.323 total time=  19.8s
# [CV 2/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.358 total time=  19.3s
# [CV 3/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.333 total time=  19.8s
# [CV 4/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.353 total time=  20.0s
# [CV 5/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.374 total time=  19.5s
# [CV 1/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.123 total time=  26.1s
# [CV 2/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.149 total time=  25.4s
# [CV 3/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.129 total time=  26.0s
# [CV 4/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.149 total time=  26.1s
# [CV 5/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.190 total time=  25.8s
# [CV 1/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.533 total time=  14.1s
# [CV 2/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.574 total time=  14.1s
# [CV 3/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.553 total time=  14.3s
# [CV 4/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.570 total time=  13.9s
# [CV 5/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.598 total time=  14.1s
# [CV 1/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.285 total time=  20.7s
# [CV 2/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.314 total time=  20.2s
# [CV 3/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.295 total time=  21.6s
# [CV 4/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.322 total time=  21.8s
# [CV 5/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.355 total time=  20.6s
# [CV 1/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.091 total time=  26.7s
# [CV 2/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.096 total time=  26.2s
# [CV 3/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.075 total time=  26.2s
# [CV 4/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.109 total time=  26.4s
# [CV 5/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.146 total time=  29.3s
# [CV 1/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.579 total time=  14.1s
# [CV 2/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.612 total time=  14.2s
# [CV 3/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.583 total time=  13.8s
# [CV 4/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.610 total time=  13.8s
# [CV 5/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.630 total time=  13.6s
# [CV 1/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.329 total time=  19.7s
# [CV 2/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.347 total time=  20.1s
# [CV 3/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.326 total time=  20.8s
# [CV 4/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.359 total time=  22.9s
# [CV 5/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.361 total time=  19.8s
# [CV 1/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.148 total time=  26.3s
# [CV 2/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.160 total time=  25.6s
# [CV 3/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.122 total time=  27.4s
# [CV 4/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.150 total time=  26.0s
# [CV 5/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.203 total time=  25.9s
# [CV 1/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.521 total time=  14.7s
# [CV 2/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.571 total time=  14.5s
# [CV 3/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.553 total time=  14.4s
# [CV 4/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.568 total time=  14.5s
# [CV 5/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.592 total time=  14.4s
# [CV 1/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.289 total time=  20.7s
# [CV 2/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.299 total time=  20.7s
# [CV 3/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.285 total time=  21.0s
# [CV 4/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.320 total time=  21.0s
# [CV 5/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.359 total time=  23.1s
# [CV 1/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.102 total time=  27.7s
# [CV 2/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.118 total time=  28.5s
# [CV 3/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.087 total time=  27.8s
# [CV 4/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.101 total time=  27.0s
# [CV 5/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.159 total time=  27.5s
# [CV 1/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.577 total time=  14.1s
# [CV 2/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.590 total time=  14.0s
# [CV 3/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.594 total time=  14.0s
# [CV 4/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.619 total time=  13.3s
# [CV 5/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.633 total time=  13.5s
# [CV 1/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.323 total time=  19.1s
# [CV 2/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.358 total time=  19.3s
# [CV 3/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.333 total time=  19.5s
# [CV 4/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.353 total time=  21.0s
# [CV 5/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.374 total time=  20.0s
# [CV 1/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.123 total time=  25.9s
# [CV 2/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.168 total time=  25.8s
# [CV 3/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.129 total time=  25.6s
# [CV 4/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.149 total time=  25.5s
# [CV 5/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.177 total time=  25.5s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 20, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -6.103322951673948
#  MAE: 5.918055
# possible features: ['MP3', 'MP_pg3', 'FG3', 'FG_pg3', 'FGA3', 'FGA_pg3', 'FG%_pg3', '2P3', '2P_pg3', '2PA3', '2PA_pg3', '2P%_pg3', '3P3', '3P_pg3', '3PA3', '3PA_pg3', '3P%_pg3', 'FT3', 'FT_pg3', 'FTA3', 'FTA_pg3', 'FT%3', 'FT%_pg3', 'TS%_pg3', 'ORB3', 'ORB_pg3', 'DRB3', 'DRB_pg3', 'TRB3', 'TRB_pg3', 'AST3', 'AST_pg3', 'STL3', 'STL_pg3', 'BLK3', 'BLK_pg3', 'TOV3', 'TOV_pg3', 'PF3', 'PF_pg3', 'PTS3', 'PTS_pg3', 'GmSc3', 'GmSc_pg3', 'BPM_pg3', 'EFF3', 'EFF_pg3', 'g_MP3Rank3', 'g_FG3Rank3', 'g_FGARank3', 'g_FG%Rank3', 'g_2PRank3', 'g_2PARank3', 'g_2P%Rank3', 'g_3PRank3', 'g_3PARank3', 'g_3P%Rank3', 'g_FTRank3', 'g_FTARank3', 'g_FT%Rank3', 'g_TS%Rank3', 'g_ORBRank3', 'g_DRBRank3', 'g_TRBRank3', 'g_ASTRank3', 'g_STLRank3', 'g_BLKRank3', 'g_TOVRank3', 'g_PFRank3', 'g_PTSRank3', 'g_GMScRank3', 'g_BPMRank3', 'g_EFFRank3', 'g_DKPts3', 'g_DKPtsRank3', 'MinutesPlayed', 'MinutesPlayed_pg', 'FieldGoals', 'FieldGoals_pg', 'FieldGoalAttempts', 'FieldGoalAttempts_pg', 'FieldGoalPercentage_pg', 'TwoPointers', 'TwoPointers_pg', 'TwoPointAttempts', 'TwoPointAttempts_pg', 'TwoPointPercentage_pg', 'ThreePointers', 'ThreePointers_pg', 'ThreePointAttempts', 'ThreePointAttempts_pg', 'ThreePointPercentage_pg', 'FreeThrows', 'FreeThrows_pg', 'FreeThrowAttempts', 'FreeThrowAttempts_pg', 'FreeThrowPercentage_pg', 'TrueShootingPercentage_pg', 'OffensiveRebounds', 'OffensiveRebounds_pg', 'DefensiveRebounds', 'DefensiveRebounds_pg', 'TotalRebounds', 'TotalRebounds_pg', 'Assists', 'Assists_pg', 'Steals', 'Steals_pg', 'Blocks', 'Blocks_pg', 'Turnovers', 'Turnovers_pg', 'PersonalFouls', 'PersonalFouls_pg', 'Points', 'Points_pg', 'GameScore_pg', 'BoxPlusMinus_pg', 'Efficiency_pg', 'g_DKPts_szn', 'g_DKPtsRank_szn', 'def_MP3', 'def_MP_pg3', 'def_FG3', 'def_FG_pg3', 'def_FGA3', 'def_FGA_pg3', 'def_FG%_pg3', 'def_2P3', 'def_2P_pg3', 'def_2PA3', 'def_2PA_pg3', 'def_2P%_pg3', 'def_3P3', 'def_3P_pg3', 'def_3PA3', 'def_3PA_pg3', 'def_3P%_pg3', 'def_FT3', 'def_FT_pg3', 'def_FTA3', 'def_FTA_pg3', 'def_FT%_pg3', 'def_TS%_pg3', 'def_ORB3', 'def_ORB_pg3', 'def_DRB3', 'def_DRB_pg3', 'def_TRB3', 'def_TRB_pg3', 'def_AST3', 'def_AST_pg3', 'def_STL3', 'def_STL_pg3', 'def_BLK3', 'def_BLK_pg3', 'def_TOV3', 'def_TOV_pg3', 'def_PF3', 'def_PF_pg3', 'def_PTS3', 'def_PTS_pg3', 'def_GmSc3', 'def_GmSc_pg3', 'def_BPM_pg3', 'def_EFF3', 'def_EFF_pg3', 'def_g_MP3Rank3', 'def_g_FG3Rank3', 'def_g_FGARank3', 'def_g_FG%Rank3', 'def_g_2PRank3', 'def_g_2PARank3', 'def_g_2P%Rank3', 'def_g_3PRank3', 'def_g_3PARank3', 'def_g_3P%Rank3', 'def_g_FTRank3', 'def_g_FTARank3', 'def_g_FT%Rank3', 'def_g_TS%Rank3', 'def_g_ORBRank3', 'def_g_DRBRank3', 'def_g_TRBRank3', 'def_g_ASTRank3', 'def_g_STLRank3', 'def_g_BLKRank3', 'def_g_TOVRank3', 'def_g_PFRank3', 'def_g_PTSRank3', 'def_g_GMScRank3', 'def_g_BPMRank3', 'def_g_EFFRank3', 'def_g_DKPts3', 'def_g_DKPtsRank3', 'def_MinutesPlayed', 'def_MinutesPlayed_pg', 'def_FieldGoals', 'def_FieldGoals_pg', 'def_FieldGoalAttempts', 'def_FieldGoalAttempts_pg', 'def_FieldGoalPercentage_pg', 'def_TwoPointers', 'def_TwoPointers_pg', 'def_TwoPointAttempts', 'def_TwoPointAttempts_pg', 'def_TwoPointPercentage_pg', 'def_ThreePointers', 'def_ThreePointers_pg', 'def_ThreePointAttempts', 'def_ThreePointAttempts_pg', 'def_ThreePointPercentage_pg', 'def_FreeThrows', 'def_FreeThrows_pg', 'def_FreeThrowAttempts', 'def_FreeThrowAttempts_pg', 'def_FreeThrowPercentage_pg', 'def_TrueShootingPercentage_pg', 'def_OffensiveRebounds', 'def_OffensiveRebounds_pg', 'def_DefensiveRebounds', 'def_DefensiveRebounds_pg', 'def_TotalRebounds', 'def_TotalRebounds_pg', 'def_Assists', 'def_Assists_pg', 'def_Steals', 'def_Steals_pg', 'def_Blocks', 'def_Blocks_pg', 'def_Turnovers', 'def_Turnovers_pg', 'def_PersonalFouls', 'def_PersonalFouls_pg', 'def_Points', 'def_Points_pg', 'def_GameScore_pg', 'def_BoxPlusMinus_pg', 'def_Efficiency_pg', 'def_g_DKPts_szn', 'def_g_DKPtsRank_szn']
# ['models/LGBM_models/G_model_allfeats.pkl']

# %%
# get top 50 features
dset = pd.DataFrame({'attr':X_train.columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr50 = dset['attr'][0:50].tolist()

# hyperparameter tuning for 50 features
best_params_50 = hyperparameter_tuning(attr50)

""" MODEL SELECTION (50 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_50)
"""                 """

#print top50 features
print('T50 features', attr50, '\n')

# Fit model, make predictions with t50 features
model.fit(X_train[attr50], Y_train)
preds50 = model.predict(X_test[attr50])

# add model performance to pdf dataframe
pdf['Pred_G_DKPts_50'] = preds50
pdf['Predicted50Rank'] = pdf.groupby(['Season','Date'])['Pred_G_DKPts_50'].rank(method='min', ascending = False)

# save the model to disk
filename = 'models/LGBM_models/G_model_50feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.881 total time=  12.1s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.878 total time=  11.7s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6
5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.923 total time=  11.0s
# [CV 5/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.977 total time=  11.0s
# [CV 1/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.658 total time=  16.0s
# [CV 2/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.650 total time=  16.2s
# [CV 3/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.681 total time=  16.0s
# [CV 4/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.656 total time=  16.3s
# [CV 5/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.736 total time=  16.0s
# [CV 1/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.469 total time=  21.4s
# [CV 2/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.476 total time=  21.4s
# [CV 3/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.477 total time=  21.4s
# [CV 4/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.474 total time=  21.3s
# [CV 5/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.534 total time=  21.4s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 40, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -6.4212499933988765
#  MAE: 6.241740
# T50 features ['def_BoxPlusMinus_pg', 'def_g_BLKRank3', 'def_ThreePointPercentage_pg', 'def_g_ORBRank3', 'def_TwoPointPercentage_pg', 'g_BLKRank3', 'def_g_STLRank3', 'def_FreeThrowPercentage_pg', 'g_ORBRank3', 'def_g_PFRank3', 'def_PersonalFouls_pg', 'def_g_TOVRank3', 'g_PFRank3', 'Blocks_pg', 'g_STLRank3', 'def_3P%_pg3', 'PersonalFouls_pg', 'Steals_pg', 'BoxPlusMinus_pg', 'def_2P%_pg3', 'g_TOVRank3', 'def_g_2P%Rank3', 'def_BPM_pg3', 'def_OffensiveRebounds_pg', 'def_TrueShootingPercentage_pg', 'def_g_ASTRank3', 'def_g_FT%Rank3', 'def_FieldGoalPercentage_pg', 'def_Turnovers_pg', 'TwoPointPercentage_pg', 'def_Steals_pg', 'def_Blocks_pg', 'OffensiveRebounds_pg', '2P%_pg3', 'ThreePointPercentage_pg', 'g_3P%Rank3', 'def_FG%_pg3', 'def_g_3P%Rank3', 'def_MinutesPlayed_pg', 'def_g_3PARank3', 'g_ASTRank3', 'g_FT%Rank3', '3P%_pg3', 'g_2P%Rank3', 'def_g_3PRank3', 'BPM_pg3', 'Assists_pg', 'Turnovers_pg', 'FieldGoalPercentage_pg', 'def_TS%_pg3']
# ['models/LGBM_models/G_model_50feats.pkl']

# %%
# Using Top 50 Features, Find Top 30 Features
model.fit(X_train[attr50], Y_train)
dset = pd.DataFrame({'attr':X_train[attr50].columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr30 = dset['attr'][0:30].tolist()

# hyperparameter tuning for 30 features
best_params_30 = hyperparameter_tuning(attr30)

""" MODEL SELECTION (30 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_30)
"""                 """

#print top30 features
print('T30 features', attr30, '\n')

# Fit model, make predictions with t30 features
model.fit(X_train[attr30], Y_train)
preds30 = model.predict(X_test[attr30])

# add model performance to pdf dataframe
pdf['Pred_G_DKPts_30'] = preds30
pdf['Predicted30Rank'] = pdf.groupby(['Season','Date'])['Pred_G_DKPts_30'].rank(method='min', ascending = False)

# save the model to disk
filename = 'models/LGBM_models/G_model_30feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.193 total time=  11.0s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7
5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.282 total time=  10.7s
# [CV 5/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.328 total time=  10.7s
# [CV 1/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.006 total time=  15.5s
# [CV 2/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.027 total time=  15.5s
# [CV 3/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.069 total time=  15.6s
# [CV 4/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.062 total time=  15.5s
# [CV 5/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.077 total time=  15.5s
# [CV 1/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.796 total time=  20.8s
# [CV 2/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.803 total time=  20.7s
# [CV 3/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.890 total time=  20.7s
# [CV 4/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.833 total time=  20.8s
# [CV 5/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.881 total time=  20.8s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 20, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -6.766002210461503
#  MAE: 6.608481
# T30 features ['def_Turnovers_pg', 'def_g_STLRank3', 'OffensiveRebounds_pg', 'def_PersonalFouls_pg', 'def_FreeThrowPercentage_pg', 'def_g_ORBRank3', 'def_BoxPlusMinus_pg', 'def_g_FT%Rank3', 'def_ThreePointPercentage_pg', 'g_STLRank3', 'def_g_PFRank3', 'def_OffensiveRebounds_pg', 'def_g_ASTRank3', 'Blocks_pg', 'def_g_BLKRank3', 'def_MinutesPlayed_pg', 'PersonalFouls_pg', 'g_BLKRank3', 'ThreePointPercentage_pg', 'def_g_TOVRank3', 'g_ORBRank3', 'def_Steals_pg', 'g_PFRank3', 'def_Blocks_pg', 'def_BPM_pg3', 'BPM_pg3', 'Steals_pg', 'def_TwoPointPercentage_pg', 'BoxPlusMinus_pg', 'g_TOVRank3']
# ['models/LGBM_models/G_model_30feats.pkl']

# %%
# Using Top 30 Features, Find Top 20 Features
model.fit(X_train[attr30], Y_train)
dset = pd.DataFrame({'attr':X_train[attr30].columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr20 = dset['attr'][0:20].tolist()

# hyperparameter tuning for 20 features
best_params_20 = hyperparameter_tuning(attr20)

""" MODEL SELECTION (20 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_20)
"""                 """

#print top20 features
print('T20 features', attr20, '\n')

# Fit model, make predictions with t20 features
model.fit(X_train[attr20], Y_train)
preds20 = model.predict(X_test[attr20])

# add model performance to pdf dataframe
pdf['Pred_G_DKPts_20'] = preds20
pdf['Predicted20Rank'] = pdf.groupby(['Season','Date'])['Pred_G_DKPts_20'].rank(method='min', ascending = False)

# save the model to disk
filename = 'models/LGBM_models/G_model_20feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.289 total time=  10.8s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.307 total time=  10.9s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.364 total time=  10.9s
# [CV 4/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.317 total time=  10.8s
# [CV 5/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.364 total time=  10.7s
# [CV 1/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.066 total time=  15.9s
# [CV 2/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.090 total time=  15.8s
# [CV 3/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.119 total time=  15.8s
# [CV 4/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.058 total time=  15.7s
# [CV 5/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.135 total time=  15.7s
# [CV 1/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.851 total time=  21.2s
# [CV 2/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.871 total time=  21.1s
# [CV 3/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.906 total time=  21.0s
# [CV 4/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.871 total time=  21.1s
# [CV 5/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6
5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.026 total time=  20.5s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 20, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -6.885528117739452
#  MAE: 6.715519
# T20 features ['ThreePointPercentage_pg', 'g_TOVRank3', 'def_TwoPointPercentage_pg', 'BPM_pg3', 'def_BPM_pg3', 'PersonalFouls_pg', 'def_g_ORBRank3', 'BoxPlusMinus_pg', 'def_BoxPlusMinus_pg', 'Blocks_pg', 'def_g_FT%Rank3', 'g_BLKRank3', 'OffensiveRebounds_pg', 'def_ThreePointPercentage_pg', 'def_g_BLKRank3', 'def_OffensiveRebounds_pg', 'def_g_STLRank3', 'Steals_pg', 'g_ORBRank3', 'def_PersonalFouls_pg']
# ['models/LGBM_models/G_model_20feats.pkl']

# %%
# Using Top 20 Features, Find Top 10 Features
model.fit(X_train[attr20], Y_train)
dset = pd.DataFrame({'attr':X_train[attr20].columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr10 = dset['attr'][0:10].tolist()

# hyperparameter tuning for 10 features
best_params_10 = hyperparameter_tuning(attr10)

""" MODEL SELECTION (10 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_10)
"""                 """

#print top10 features
print('T10 features', attr10, '\n')

# Fit model, make predictions with t10 features
model.fit(X_train[attr10], Y_train)
preds10 = model.predict(X_test[attr10])

# add model performance to pdf dataframe
pdf['Pred_G_DKPts_10'] = preds10
pdf['Predicted10Rank'] = pdf.groupby(['Season','Date'])['Pred_G_DKPts_10'].rank(method='min', ascending = False)

# save the model to disk
filename = 'models/LGBM_models/G_model_10feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.439 total time=  10.4s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.350 total time=  10.3s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.489 total time=  10.4s
# [CV 4/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.453 total time=  10.4s
# [CV 5/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.450 total time=  10.4s
# [CV 1/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.221 total time=  15.3s
# [CV 2/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.141 total time=  15.2s
# [CV 3/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.280 total time=  15.1s
# [CV 4/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.214 total time=  15.3s
# [CV 5/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.231 total time=  15.5s
# [CV 1/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.015 total time=  20.6s
# [CV 2/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.965 total time=  20.4s
# [CV 3/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.071 total time=  20.4s
# [CV 4/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.053 total time=  20.4s
# [CV 5/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.035 total time=  20.3s
# [CV 1/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.540 total time=  10.3s
# [CV 2/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.452 total time=  10.2s
# [CV 3/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.591 total time=  10.3s
# [CV 4/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.585 total time=  10.2s
# [CV 5/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.537 total time=  10.3s
# [CV 1/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.353 total time=  15.0s
# [CV 2/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.286 total time=  14.9s
# [CV 3/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.408 total time=  15.0s
# [CV 4/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.396 total time=  15.0s
# [CV 5/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.363 total time=  14.9s
# [CV 1/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.184 total time=  20.0s
# [CV 2/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.112 total time=  20.1s
# [CV 3/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.245 total time=  20.6s
# [CV 4/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.226 total time=  20.0s
# [CV 5/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.204 total time=  20.0s
# [CV 1/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.433 total time=  10.4s
# [CV 2/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.355 total time=  10.4s
# [CV 3/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.493 total time=  10.4s
# [CV 4/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.457 total time=  10.3s
# [CV 5/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.467 total time=  10.3s
# [CV 1/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.218 total time=  15.2s
# [CV 2/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.120 total time=  15.1s
# [CV 3/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.262 total time=  15.2s
# [CV 4/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.254 total time=  15.3s
# [CV 5/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.253 total time=  15.1s
# [CV 1/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.026 total time=  20.5s
# [CV 2/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.944 total time=  20.4s
# [CV 3/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.070 total time=  20.3s
# [CV 4/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.030 total time=  20.4s
# [CV 5/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.027 total time=  20.3s
# [CV 1/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.542 total time=  10.3s
# [CV 2/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.456 total time=  10.2s
# [CV 3/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.612 total time=  10.2s
# [CV 4/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.582 total time=  10.2s
# [CV 5/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.537 total time=  10.2s
# [CV 1/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.379 total time=  14.8s
# [CV 2/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.264 total time=  14.9s
# [CV 3/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.417 total time=  14.8s
# [CV 4/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.386 total time=  14.9s
# [CV 5/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.396 total time=  14.9s
# [CV 1/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.217 total time=  20.0s
# [CV 2/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.100 total time=  19.9s
# [CV 3/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.232 total time=  19.9s
# [CV 4/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.234 total time=  20.0s
# [CV 5/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.201 total time=  19.9s
# [CV 1/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.438 total time=  10.4s
# [CV 2/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.351 total time=  10.4s
# [CV 3/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.489 total time=  10.4s
# [CV 4/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.452 total time=  10.4s
# [CV 5/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.450 total time=  10.3s
# [CV 1/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.222 total time=  15.1s
# [CV 2/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.143 total time=  15.2s
# [CV 3/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.280 total time=  15.2s
# [CV 4/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.214 total time=  15.1s
# [CV 5/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.231 total time=  15.1s
# [CV 1/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.014 total time=  20.3s
# [CV 2/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.965 total time=  20.4s
# [CV 3/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.071 total time=  20.4s
# [CV 4/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.052 total time=  20.4s
# [CV 5/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.034 total time=  20.3s
# [CV 1/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.540 total time=  10.1s
# [CV 2/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.452 total time=  10.2s
# [CV 3/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.591 total time=  10.2s
# [CV 4/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.585 total time=  10.2s
# [CV 5/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-8.538 total time=  10.2s
# [CV 1/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.353 total time=  14.9s
# [CV 2/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.286 total time=  14.8s
# [CV 3/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.408 total time=  14.9s
# [CV 4/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.396 total time=  14.9s
# [CV 5/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-8.374 total time=  14.9s
# [CV 1/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.184 total time=  20.0s
# [CV 2/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.112 total time=  20.4s
# [CV 3/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.245 total time=  20.1s
# [CV 4/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.226 total time=  20.0s
# [CV 5/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-8.204 total time=  20.1s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 20, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -8.019179556860237
#  MAE: 7.892548
# T10 features ['g_TOVRank3', 'def_TwoPointPercentage_pg', 'def_ThreePointPercentage_pg', 'def_BPM_pg3', 'def_g_ORBRank3', 'def_BoxPlusMinus_pg', 'PersonalFouls_pg', 'def_g_FT%Rank3', 'def_PersonalFouls_pg', 'def_g_STLRank3']
# ['models/LGBM_models/G_model_10feats.pkl']

# %%
# write predictions to csv
pdf.to_csv(etl_dir + 'g_predictions_lgbm_50_30_20_15_10.csv')

# create df to summarize results

feature_sets = ['all', '50', '30', '20', '10']

mae_values = [
    "{:.2f}".format(mean_absolute_error(Y_test, preds_all)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds50)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds30)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds20)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds10))
]

results_df = pd.DataFrame({'Features' : feature_sets, 'MAE' : mae_values})

results_df.style.hide_index()
display(results_df)
# Out:
#   Features   MAE
# 0      all  5.92
# 1       50  6.24
# 2       30  6.61
# 3       20  6.72
# 4       10  7.89

# %%
pdf
# Out:
#        Season  Date Team Defense             Player  Act_G_DKPtsRank  \
# 0        2014   471  CHO     BOS      P.J. Hairston             86.0
# 1        2014   358  POR     MIN    Wesley Matthews             20.0
# 2        2014   450  MEM     CHI       Vince Carter             63.0
# 3        2017   819  SAS     MIA      Kyle Anderson             31.0
# 4        2020  1328  MIN     NOP    Anthony Edwards             40.0
# ...       ...   ...  ...     ...                ...              ...
# 40170    2019  1244  IND     CHI        Jeremy Lamb             33.0
# 40171    2016   777  BRK     DAL       Caris LeVert            101.0
# 40172    2016   685  ORL     MEM      Evan Fournier             15.0
# 40173    2015   520  CHO     MIL         Jeremy Lin             63.0
# 40174    2016   673  OKC     BRK  Russell Westbrook              1.0
#
#        Act_G_DKPts  Pred_G_DKPts_all  PredictedallRank  Pred_G_DKPts_50  \
# 0              5.6         10.995620              24.0         9.446317
# 1             30.2         30.514159               3.0        25.701748
# 2             12.4         10.624259              17.0         9.813612
# 3             30.0         21.847746               9.0        22.659101
# 4             24.7         27.698950               7.0        24.707482
# ...            ...               ...               ...              ...
# 40170         21.0         22.411779               9.0        20.095369
# 40171          8.6         14.249328              26.0        11.808886
# 40172         31.0         32.140805               4.0        33.642789
# 40173         16.6         20.525212              12.0        27.653902
# 40174         61.5         57.068446               1.0        52.446674
#
#        Predicted50Rank  Pred_G_DKPts_30  Predicted30Rank  Pred_G_DKPts_20  \
# 0                 22.0        10.527105             23.0        10.489193
# 1                  9.0        26.221791              9.0        26.343586
# 2                 17.0        10.204702             17.0        11.603103
# 3                  9.0        16.887598             14.0        15.570963
# 4                 10.0        14.942860             21.0        16.926019
# ...                ...              ...              ...              ...
# 40170             13.0        20.134261             13.0        22.467683
# 40171             33.0        12.108423             33.0        11.603869
# 40172              4.0        31.384204              3.0        31.289650
# 40173              5.0        28.652697              4.0        24.728580
# 40174              1.0        50.896201              1.0        60.384953
#
#        Predicted20Rank  Pred_G_DKPts_10  Predicted10Rank
# 0                 24.0        11.759069             25.0
# 1                  6.0        25.294755              9.0
# 2                 15.0        12.009417             16.0
# 3                 20.0        16.284435             16.0
# 4                 17.0        27.987111              7.0
# ...                ...              ...              ...
# 40170              8.0        18.303028             11.0
# 40171             32.0        12.167967             33.0
# 40172              3.0        32.353490              4.0
# 40173              7.0        35.232854              3.0
# 40174              1.0        43.274085              1.0
#
# [40175 rows x 17 columns]

# %% [markdown]
# ## Forward Model

# %%
"""
"""

import os
import pickle
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from lightgbm import LGBMRegressor
import xgboost as xgb
from sklearn.metrics import mean_absolute_error

from sklearn.feature_selection import RFE

working_directory = 'D:/machine_learning/DFS/NBA/NBA_moredata'
os.chdir(working_directory)
data_dir = 'Data/'
etl_dir = 'Data/ETL/'

player_stats = pd.read_csv(data_dir + 'player_stats_all.csv', index_col = 0)
f_vs = pd.read_csv(etl_dir + 'f_stats.csv', index_col = 0)

f_vs = f_vs.rename(columns={'Opp':'Defense', 'Team_x' : 'Team'})

print(f_vs.columns.tolist())

#Grab Only Necessary Columns & Filter Only To F Data
f_act_stats = player_stats[(player_stats['Pos.']=='F') | (player_stats['Pos.']=='F-G') | (player_stats['Pos.']=='G-F') | (player_stats['Pos.']=='F-C')].copy().reset_index(drop=True)

f_act_stats = f_act_stats.fillna(0)

f_act_stats.drop(list(set(f_act_stats.columns) - set(f_vs)), axis = 1, inplace = True)

#Calculate The Draftkings Points for each player on each date
f_act_stats['Act_F_DKPts'] = (f_act_stats['3P'] * 1 + f_act_stats['AST'] * 1.5 +\
                           f_act_stats['BLK'] * 3 + f_act_stats['FG'] * 2 +\
                           f_act_stats['FT'] * 1 + f_act_stats['TRB'] * 1.2 +\
                           f_act_stats['STL'] * 3 + f_act_stats['TOV'] * -1)

#G DK PTS Rank For The Given Season & Date Pair
f_act_stats['Act_F_DKPtsRank'] = f_act_stats.groupby(['Season','Date'])['Act_F_DKPts'].rank(method='min', ascending = False)

#Columns We Want To Add To Dataset
keep_cols = ['Season','Date','Player','Act_F_DKPtsRank','Act_F_DKPts']

#Append Actual DK Pts Rank & DK Pts
f_vs_act = pd.merge(f_vs, f_act_stats[keep_cols], how = 'left', on = ['Season','Date','Player'])
f_vs_act = f_vs_act[f_vs_act['Act_F_DKPts']>0].reset_index(drop=True)

#Make sure we have no duplicated columns or infinity errors
f_vs_act = f_vs_act.loc[:,~f_vs_act.columns.duplicated()]
f_vs_act = f_vs_act.replace([np.inf, -np.inf], np.nan)
f_vs_act.to_csv(etl_dir + 'g_v_def_stats.csv')

#Columns We Can't Include In Our Features Datasets
dcols = ['Age',
         'at',
         'Result',
         'GS',
         'FG',
         'FGA',
         'FG%',
         '2P',
         '2PA',
         '2P%',
         '3P',
         '3PA',
         '3P%',
         'FT',
         'FTA',
         'FT%',
         'TS%',
         'ORB',
         'DRB',
         'TRB',
         'AST',
         'STL',
         'BLK',
         'TOV',
         'PF',
         'PTS',
         'GmSc',
         'BPM',
         'Pos.',
         'Month',
         'Year',
         'Team_y',
         'Act_F_DKPts',
         'EFF',
         'MP'
]


more_dcols = ['Season', 'Date', 'Team', 'Defense', 'Player', 'Act_F_DKPtsRank']

# f_vs_act.drop_duplicates(subset=['Player', 'Date'], keep='first', inplace = True, ignore_index = True)

X = f_vs_act.drop(dcols, axis = 1)
Y = f_vs_act['Act_F_DKPts']

from sklearn.model_selection import train_test_split

#Create Training and Testing DataSets
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.25, random_state=42)

X_train.reset_index(inplace = True, drop=True)
X_test.reset_index(inplace = True, drop=True)
Y_train.reset_index(inplace = True, drop=True)
Y_test.reset_index(inplace = True, drop=True)

print('Training set size:', len(X_train))
print('Testing set size:', len(X_test))

pred_df = pd.concat([X_test, Y_test], axis = 1)

X_train.drop(more_dcols, axis = 1, inplace = True)
X_test.drop(more_dcols, axis = 1, inplace = True)
# Out:
# ['Player', 'Date', 'Age', 'Team', 'at', 'Defense', 'Result', 'GS', 'MP', 'FG', 'FGA', 'FG%', '2P', '2PA', '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'TS%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', 'BPM', 'Pos.', 'EFF', 'Month', 'Year', 'Season', 'MP3', 'MP_pg3', 'FG3', 'FG_pg3', 'FGA3', 'FGA_pg3', 'FG%_pg3', '2P3', '2P_pg3', '2PA3', '2PA_pg3', '2P%_pg3', '3P3', '3P_pg3', '3PA3', '3PA_pg3', '3P%_pg3', 'FT3', 'FT_pg3', 'FTA3', 'FTA_pg3', 'FT%3', 'FT%_pg3', 'TS%_pg3', 'ORB3', 'ORB_pg3', 'DRB3', 'DRB_pg3', 'TRB3', 'TRB_pg3', 'AST3', 'AST_pg3', 'STL3', 'STL_pg3', 'BLK3', 'BLK_pg3', 'TOV3', 'TOV_pg3', 'PF3', 'PF_pg3', 'PTS3', 'PTS_pg3', 'GmSc3', 'GmSc_pg3', 'BPM_pg3', 'EFF3', 'EFF_pg3', 'f_MP3Rank3', 'f_FG3Rank3', 'f_FGARank3', 'f_FG%Rank3', 'f_2PRank3', 'f_2PARank3', 'f_2P%Rank3', 'f_3PRank3', 'f_3PARank3', 'f_3P%Rank3', 'f_FTRank3', 'f_FTARank3', 'f_FT%Rank3', 'f_TS%Rank3', 'f_ORBRank3', 'f_DRBRank3', 'f_TRBRank3', 'f_ASTRank3', 'f_STLRank3', 'f_BLKRank3', 'f_TOVRank3', 'f_PFRank3', 'f_PTSRank3', 'f_GMScRank3', 'f_BPMRank3', 'f_EFFRank3', 'f_DKPts3', 'f_DKPtsRank3', 'MinutesPlayed', 'MinutesPlayed_pg', 'FieldGoals', 'FieldGoals_pg', 'FieldGoalAttempts', 'FieldGoalAttempts_pg', 'FieldGoalPercentage_pg', 'TwoPointers', 'TwoPointers_pg', 'TwoPointAttempts', 'TwoPointAttempts_pg', 'TwoPointPercentage_pg', 'ThreePointers', 'ThreePointers_pg', 'ThreePointAttempts', 'ThreePointAttempts_pg', 'ThreePointPercentage_pg', 'FreeThrows', 'FreeThrows_pg', 'FreeThrowAttempts', 'FreeThrowAttempts_pg', 'FreeThrowPercentage_pg', 'TrueShootingPercentage_pg', 'OffensiveRebounds', 'OffensiveRebounds_pg', 'DefensiveRebounds', 'DefensiveRebounds_pg', 'TotalRebounds', 'TotalRebounds_pg', 'Assists', 'Assists_pg', 'Steals', 'Steals_pg', 'Blocks', 'Blocks_pg', 'Turnovers', 'Turnovers_pg', 'PersonalFouls', 'PersonalFouls_pg', 'Points', 'Points_pg', 'GameScore_pg', 'BoxPlusMinus_pg', 'Efficiency_pg', 'f_DKPts_szn', 'f_DKPtsRank_szn', 'def_MP3', 'def_MP_pg3', 'def_FG3', 'def_FG_pg3', 'def_FGA3', 'def_FGA_pg3', 'def_FG%_pg3', 'def_2P3', 'def_2P_pg3', 'def_2PA3', 'def_2PA_pg3', 'def_2P%_pg3', 'def_3P3', 'def_3P_pg3', 'def_3PA3', 'def_3PA_pg3', 'def_3P%_pg3', 'def_FT3', 'def_FT_pg3', 'def_FTA3', 'def_FTA_pg3', 'def_FT%_pg3', 'def_TS%_pg3', 'def_ORB3', 'def_ORB_pg3', 'def_DRB3', 'def_DRB_pg3', 'def_TRB3', 'def_TRB_pg3', 'def_AST3', 'def_AST_pg3', 'def_STL3', 'def_STL_pg3', 'def_BLK3', 'def_BLK_pg3', 'def_TOV3', 'def_TOV_pg3', 'def_PF3', 'def_PF_pg3', 'def_PTS3', 'def_PTS_pg3', 'def_GmSc3', 'def_GmSc_pg3', 'def_BPM_pg3', 'def_EFF3', 'def_EFF_pg3', 'def_f_MP3Rank3', 'def_f_FG3Rank3', 'def_f_FGARank3', 'def_f_FG%Rank3', 'def_f_2PRank3', 'def_f_2PARank3', 'def_f_2P%Rank3', 'def_f_3PRank3', 'def_f_3PARank3', 'def_f_3P%Rank3', 'def_f_FTRank3', 'def_f_FTARank3', 'def_f_FT%Rank3', 'def_f_TS%Rank3', 'def_f_ORBRank3', 'def_f_DRBRank3', 'def_f_TRBRank3', 'def_f_ASTRank3', 'def_f_STLRank3', 'def_f_BLKRank3', 'def_f_TOVRank3', 'def_f_PFRank3', 'def_f_PTSRank3', 'def_f_GMScRank3', 'def_f_BPMRank3', 'def_f_EFFRank3', 'def_f_DKPts3', 'def_f_DKPtsRank3', 'def_MinutesPlayed', 'def_MinutesPlayed_pg', 'def_FieldGoals', 'def_FieldGoals_pg', 'def_FieldGoalAttempts', 'def_FieldGoalAttempts_pg', 'def_FieldGoalPercentage_pg', 'def_TwoPointers', 'def_TwoPointers_pg', 'def_TwoPointAttempts', 'def_TwoPointAttempts_pg', 'def_TwoPointPercentage_pg', 'def_ThreePointers', 'def_ThreePointers_pg', 'def_ThreePointAttempts', 'def_ThreePointAttempts_pg', 'def_ThreePointPercentage_pg', 'def_FreeThrows', 'def_FreeThrows_pg', 'def_FreeThrowAttempts', 'def_FreeThrowAttempts_pg', 'def_FreeThrowPercentage_pg', 'def_TrueShootingPercentage_pg', 'def_OffensiveRebounds', 'def_OffensiveRebounds_pg', 'def_DefensiveRebounds', 'def_DefensiveRebounds_pg', 'def_TotalRebounds', 'def_TotalRebounds_pg', 'def_Assists', 'def_Assists_pg', 'def_Steals', 'def_Steals_pg', 'def_Blocks', 'def_Blocks_pg', 'def_Turnovers', 'def_Turnovers_pg', 'def_PersonalFouls', 'def_PersonalFouls_pg', 'def_Point ...
# Training set size: 133440
# Testing set size: 44481
# C:\Users\Greg\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# dump non-scaled train df for external scaling to work
filename = 'scalers/f_X_train.pkl'
joblib.dump(X_train, filename)

# Scaling
from sklearn.preprocessing import StandardScaler
f_scaler = StandardScaler().fit(X_train)
X_train = pd.DataFrame(f_scaler.transform(X_train), columns = X_train.columns)
X_test = pd.DataFrame(f_scaler.transform(X_test), columns = X_test.columns)
filename = 'scalers/f_scaler.pkl'
joblib.dump(f_scaler, filename)

print('\nNum Possible Features:',len(X_train.columns.tolist()))
# Out:
# Num Possible Features: 241

# %%
# hyperparameter tuning function
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

def hyperparameter_tuning(feat_set):
    # define model for param tuning
    model = LGBMRegressor()

    # define param grid
    param_grid = {
        'random_state' : [1],
        'n_jobs' : [-1],
        'n_estimators' : [1000],
        'learning_rate': [0.1],
        'num_leaves': [62, 93, 127],
        'max_depth' :[-1, 20, 40],
        'min_child_samples' : [20, 80],
        'max_bin' : [63],
        'device' : ['gpu']
    }

    gsearch = GridSearchCV(model, param_grid, verbose = 10, scoring = 'neg_mean_absolute_error') 

    lgb_model = gsearch.fit(X_train[feat_set], Y_train)
    print('best params')
    print(gsearch.best_params_, gsearch.best_score_)
    preds_lgb_model = lgb_model.predict(X_test[feat_set])
    mae_lgb = mean_absolute_error(Y_test, preds_lgb_model)
    print(" MAE: %f" % (mae_lgb ))
    return lgb_model.best_params_

# %%
# hyperparameter tuning for all features
best_params_all = hyperparameter_tuning(X_train.columns.tolist())

""" MODEL SELECTION (ALL FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_all)
"""                 """

#print possible features
print('possible features:', X_train.columns.tolist(), '\n')

# Fit model, make predictions with all features
model.fit(X_train, Y_train)

preds_all = model.predict(X_test)

pdf = pred_df[['Season','Date','Team','Defense','Player','Act_F_DKPtsRank','Act_F_DKPts']].copy()
pdf['Pred_F_DKPts_all'] = preds_all
pdf['PredictedallRank'] = pdf.groupby(['Season','Date'])['Pred_F_DKPts_all'].rank(method='min', ascending = False)
temp_df_all = pdf[pdf['PredictedallRank']<=5]

# save the initial model to disk
filename = 'models/LGBM_models/F_model_allfeats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.095 total time=  14.2s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.119 total time=  14.0s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.110 total time=  14.0s
# [CV 4/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.076 total time=  14.0s
# [CV 5/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.139 total time=  14.0s
# [CV 1/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.718 total time=  20.1s
# [CV 2/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.774 total time=  19.9s
# [CV 3/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.713 total time=  20.0s
# [CV 4/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.700 total time=  20.2s
# [CV 5/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.747 total time=  20.1s
# [CV 1/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.410 total time=  26.6s
# [CV 2/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.456 total time=  26.5s
# [CV 3/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.440 total time=  26.5s
# [CV 4/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.372 total time=  26.6s
# [CV 5/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.477 total time=  26.6s
# [CV 1/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.143 total time=  13.6s
# [CV 2/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.180 total time=  13.5s
# [CV 3/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.150 total time=  13.6s
# [CV 4/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.134 total time=  13.5s
# [CV 5/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.194 total time=  13.6s
# [CV 1/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.765 total time=  19.4s
# [CV 2/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.809 total time=  19.2s
# [CV 3/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.800 total time=  19.3s
# [CV 4/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.760 total time=  19.4s
# [CV 5/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.821 total time=  19.3s
# [CV 1/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.485 total time=  25.5s
# [CV 2/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.507 total time=  25.4s
# [CV 3/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.477 total time=  25.4s
# [CV 4/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5
# possible features: ['MP3', 'MP_pg3', 'FG3', 'FG_pg3', 'FGA3', 'FGA_pg3', 'FG%_pg3', '2P3', '2P_pg3', '2PA3', '2PA_pg3', '2P%_pg3', '3P3', '3P_pg3', '3PA3', '3PA_pg3', '3P%_pg3', 'FT3', 'FT_pg3', 'FTA3', 'FTA_pg3', 'FT%3', 'FT%_pg3', 'TS%_pg3', 'ORB3', 'ORB_pg3', 'DRB3', 'DRB_pg3', 'TRB3', 'TRB_pg3', 'AST3', 'AST_pg3', 'STL3', 'STL_pg3', 'BLK3', 'BLK_pg3', 'TOV3', 'TOV_pg3', 'PF3', 'PF_pg3', 'PTS3', 'PTS_pg3', 'GmSc3', 'GmSc_pg3', 'BPM_pg3', 'EFF3', 'EFF_pg3', 'f_MP3Rank3', 'f_FG3Rank3', 'f_FGARank3', 'f_FG%Rank3', 'f_2PRank3', 'f_2PARank3', 'f_2P%Rank3', 'f_3PRank3', 'f_3PARank3', 'f_3P%Rank3', 'f_FTRank3', 'f_FTARank3', 'f_FT%Rank3', 'f_TS%Rank3', 'f_ORBRank3', 'f_DRBRank3', 'f_TRBRank3', 'f_ASTRank3', 'f_STLRank3', 'f_BLKRank3', 'f_TOVRank3', 'f_PFRank3', 'f_PTSRank3', 'f_GMScRank3', 'f_BPMRank3', 'f_EFFRank3', 'f_DKPts3', 'f_DKPtsRank3', 'MinutesPlayed', 'MinutesPlayed_pg', 'FieldGoals', 'FieldGoals_pg', 'FieldGoalAttempts', 'FieldGoalAttempts_pg', 'FieldGoalPercentage_pg', 'TwoPointers', 'TwoPointers_pg', 'TwoPointAttempts', 'TwoPointAttempts_pg', 'TwoPointPercentage_pg', 'ThreePointers', 'ThreePointers_pg', 'ThreePointAttempts', 'ThreePointAttempts_pg', 'ThreePointPercentage_pg', 'FreeThrows', 'FreeThrows_pg', 'FreeThrowAttempts', 'FreeThrowAttempts_pg', 'FreeThrowPercentage_pg', 'TrueShootingPercentage_pg', 'OffensiveRebounds', 'OffensiveRebounds_pg', 'DefensiveRebounds', 'DefensiveRebounds_pg', 'TotalRebounds', 'TotalRebounds_pg', 'Assists', 'Assists_pg', 'Steals', 'Steals_pg', 'Blocks', 'Blocks_pg', 'Turnovers', 'Turnovers_pg', 'PersonalFouls', 'PersonalFouls_pg', 'Points', 'Points_pg', 'GameScore_pg', 'BoxPlusMinus_pg', 'Efficiency_pg', 'f_DKPts_szn', 'f_DKPtsRank_szn', 'def_MP3', 'def_MP_pg3', 'def_FG3', 'def_FG_pg3', 'def_FGA3', 'def_FGA_pg3', 'def_FG%_pg3', 'def_2P3', 'def_2P_pg3', 'def_2PA3', 'def_2PA_pg3', 'def_2P%_pg3', 'def_3P3', 'def_3P_pg3', 'def_3PA3', 'def_3PA_pg3', 'def_3P%_pg3', 'def_FT3', 'def_FT_pg3', 'def_FTA3', 'def_FTA_pg3', 'def_FT%_pg3', 'def_TS%_pg3', 'def_ORB3', 'def_ORB_pg3', 'def_DRB3', 'def_DRB_pg3', 'def_TRB3', 'def_TRB_pg3', 'def_AST3', 'def_AST_pg3', 'def_STL3', 'def_STL_pg3', 'def_BLK3', 'def_BLK_pg3', 'def_TOV3', 'def_TOV_pg3', 'def_PF3', 'def_PF_pg3', 'def_PTS3', 'def_PTS_pg3', 'def_GmSc3', 'def_GmSc_pg3', 'def_BPM_pg3', 'def_EFF3', 'def_EFF_pg3', 'def_f_MP3Rank3', 'def_f_FG3Rank3', 'def_f_FGARank3', 'def_f_FG%Rank3', 'def_f_2PRank3', 'def_f_2PARank3', 'def_f_2P%Rank3', 'def_f_3PRank3', 'def_f_3PARank3', 'def_f_3P%Rank3', 'def_f_FTRank3', 'def_f_FTARank3', 'def_f_FT%Rank3', 'def_f_TS%Rank3', 'def_f_ORBRank3', 'def_f_DRBRank3', 'def_f_TRBRank3', 'def_f_ASTRank3', 'def_f_STLRank3', 'def_f_BLKRank3', 'def_f_TOVRank3', 'def_f_PFRank3', 'def_f_PTSRank3', 'def_f_GMScRank3', 'def_f_BPMRank3', 'def_f_EFFRank3', 'def_f_DKPts3', 'def_f_DKPtsRank3', 'def_MinutesPlayed', 'def_MinutesPlayed_pg', 'def_FieldGoals', 'def_FieldGoals_pg', 'def_FieldGoalAttempts', 'def_FieldGoalAttempts_pg', 'def_FieldGoalPercentage_pg', 'def_TwoPointers', 'def_TwoPointers_pg', 'def_TwoPointAttempts', 'def_TwoPointAttempts_pg', 'def_TwoPointPercentage_pg', 'def_ThreePointers', 'def_ThreePointers_pg', 'def_ThreePointAttempts', 'def_ThreePointAttempts_pg', 'def_ThreePointPercentage_pg', 'def_FreeThrows', 'def_FreeThrows_pg', 'def_FreeThrowAttempts', 'def_FreeThrowAttempts_pg', 'def_FreeThrowPercentage_pg', 'def_TrueShootingPercentage_pg', 'def_OffensiveRebounds', 'def_OffensiveRebounds_pg', 'def_DefensiveRebounds', 'def_DefensiveRebounds_pg', 'def_TotalRebounds', 'def_TotalRebounds_pg', 'def_Assists', 'def_Assists_pg', 'def_Steals', 'def_Steals_pg', 'def_Blocks', 'def_Blocks_pg', 'def_Turnovers', 'def_Turnovers_pg', 'def_PersonalFouls', 'def_PersonalFouls_pg', 'def_Points', 'def_Points_pg', 'def_GameScore_pg', 'def_BoxPlusMinus_pg', 'def_Efficiency_pg', 'def_f_DKPts_szn', 'def_f_DKPtsRank_szn']
# ['models/LGBM_models/F_model_allfeats.pkl']

# %%
# get top 50 features
dset = pd.DataFrame({'attr':X_train.columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr50 = dset['attr'][0:50].tolist()

# hyperparameter tuning for 50 features
best_params_50 = hyperparameter_tuning(attr50)

""" MODEL SELECTION (50 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_50)
"""                 """

#print top50 features
print('T50 features', attr50, '\n')

# Fit model, make predictions with t50 features
model.fit(X_train[attr50], Y_train)
preds50 = model.predict(X_test[attr50])

# add model performance to pdf dataframe
pdf['Pred_F_DKPts_50'] = preds50
pdf['Predicted50Rank'] = pdf.groupby(['Season','Date'])['Pred_F_DKPts_50'].rank(method='min', ascending = False)

# save the model to disk
filename = 'models/LGBM_models/F_model_50feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.471 total time=  12.5s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.529 total time=  12.4s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6
5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.585 total time=  11.6s
# [CV 1/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.165 total time=  16.8s
# [CV 2/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.248 total time=  16.4s
# [CV 3/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.177 total time=  16.7s
# [CV 4/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.162 total time=  16.8s
# [CV 5/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.223 total time=  16.6s
# [CV 1/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.852 total time=  22.4s
# [CV 2/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.939 total time=  22.3s
# [CV 3/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.883 total time=  22.9s
# [CV 4/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.851 total time=  22.8s
# [CV 5/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.905 total time=  22.6s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 20, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -5.803223643263631
#  MAE: 5.541419
# T50 features ['def_BoxPlusMinus_pg', 'def_TwoPointPercentage_pg', 'def_f_STLRank3', 'def_FreeThrowPercentage_pg', 'def_f_PFRank3', 'def_f_BLKRank3', 'def_f_ORBRank3', 'def_ThreePointPercentage_pg', 'f_BLKRank3', 'f_STLRank3', 'def_f_TOVRank3', 'f_PFRank3', 'def_PersonalFouls_pg', 'Blocks_pg', 'f_TOVRank3', 'PersonalFouls_pg', 'BoxPlusMinus_pg', 'def_Turnovers_pg', 'def_FieldGoalPercentage_pg', 'def_f_ASTRank3', 'def_BPM_pg3', 'Steals_pg', 'def_TrueShootingPercentage_pg', 'def_Blocks_pg', 'def_2P%_pg3', 'def_f_FT%Rank3', 'def_Assists_pg', 'def_OffensiveRebounds_pg', 'def_Steals_pg', 'def_MinutesPlayed_pg', 'f_ORBRank3', 'f_ASTRank3', 'def_f_3P%Rank3', 'def_f_2P%Rank3', 'BPM_pg3', 'f_FT%Rank3', 'def_f_3PARank3', 'def_f_3PRank3', 'def_f_BPMRank3', '2P%_pg3', 'def_DefensiveRebounds_pg', 'TrueShootingPercentage_pg', 'Turnovers_pg', 'TwoPointPercentage_pg', 'def_PersonalFouls', 'Assists_pg', 'def_Blocks', 'f_2P%Rank3', 'OffensiveRebounds_pg', 'def_f_DRBRank3']
# ['models/LGBM_models/F_model_50feats.pkl']

# %%
# Using Top 50 Features, Find Top 30 Features
model.fit(X_train[attr50], Y_train)
dset = pd.DataFrame({'attr':X_train[attr50].columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr30 = dset['attr'][0:30].tolist()

# hyperparameter tuning for 30 features
best_params_30 = hyperparameter_tuning(attr30)

""" MODEL SELECTION (30 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_30)
"""                 """

#print top50 features
print('T30 features', attr30, '\n')

# Fit model, make predictions with t30 features
model.fit(X_train[attr30], Y_train)
preds30 = model.predict(X_test[attr30])

# add model performance to pdf dataframe
pdf['Pred_F_DKPts_30'] = preds30
pdf['Predicted30Rank'] = pdf.groupby(['Season','Date'])['Pred_F_DKPts_30'].rank(method='min', ascending = False)

# save the initial model to disk
filename = 'models/LGBM_models/F_model_30feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.881 total time=  12.1s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.918 total time=  12.0s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6
5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.911 total time=  11.5s
# [CV 5/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.971 total time=  11.2s
# [CV 1/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.575 total time=  16.5s
# [CV 2/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.614 total time=  16.4s
# [CV 3/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.607 total time=  16.8s
# [CV 4/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.542 total time=  16.5s
# [CV 5/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.614 total time=  17.3s
# [CV 1/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.263 total time=  22.8s
# [CV 2/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.307 total time=  22.6s
# [CV 3/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.288 total time=  22.0s
# [CV 4/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.258 total time=  21.9s
# [CV 5/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.311 total time=  22.1s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 20, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -6.191034583152022
#  MAE: 5.948536
# T30 features ['def_f_BLKRank3', 'OffensiveRebounds_pg', 'Blocks_pg', 'def_BoxPlusMinus_pg', 'f_PFRank3', 'def_Assists_pg', 'PersonalFouls_pg', 'BPM_pg3', 'def_f_PFRank3', 'def_FreeThrowPercentage_pg', 'def_ThreePointPercentage_pg', 'def_Turnovers_pg', 'f_BLKRank3', 'def_OffensiveRebounds_pg', 'def_f_STLRank3', 'def_f_TOVRank3', 'f_ORBRank3', 'f_STLRank3', 'def_Steals_pg', 'def_f_ORBRank3', 'def_f_FT%Rank3', 'def_f_ASTRank3', 'def_MinutesPlayed_pg', 'TwoPointPercentage_pg', 'Steals_pg', 'BoxPlusMinus_pg', 'def_f_DRBRank3', 'f_FT%Rank3', 'def_DefensiveRebounds_pg', 'TrueShootingPercentage_pg']
# ['models/LGBM_models/F_model_30feats.pkl']

# %%
# Using Top 30 Features, Find Top 20 Features
model.fit(X_train[attr30], Y_train)
dset = pd.DataFrame({'attr':X_train[attr30].columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr20 = dset['attr'][0:20].tolist()

# hyperparameter tuning for 20 features
best_params_20 = hyperparameter_tuning(attr20)

""" MODEL SELECTION (20 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_20)
"""                 """

#print top20 features
print('T20 features', attr20, '\n')

# Fit model, make predictions with t20 features
model.fit(X_train[attr20], Y_train)
preds20 = model.predict(X_test[attr20])

# add model performance to pdf dataframe
pdf['Pred_F_DKPts_20'] = preds20
pdf['Predicted20Rank'] = pdf.groupby(['Season','Date'])['Pred_F_DKPts_20'].rank(method='min', ascending = False)

# save the model to disk
filename = 'models/LGBM_models/F_model_20feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.180 total time=  11.7s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.204 total time=  12.6s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.185 total time=  12.0s
# [CV 4/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.158 total time=  12.5s
# [CV 5/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.161 total time=  11.9s
# [CV 1/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.787 total time=  17.0s
# [CV 2/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.883 total time=  18.1s
# [CV 3/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.803 total time=  17.7s
# [CV 4/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.762 total time=  17.6s
# [CV 5/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.788 total time=  17.1s
# [CV 1/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.461 total time=  23.0s
# [CV 2/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.546 total time=  23.3s
# [CV 3/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.470 total time=  22.7s
# [CV 4/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.435 total time=  22.2s
# [CV 5/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6
5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.607 total time=  21.0s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 40, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -6.475297273304522
#  MAE: 6.277280
# T20 features ['def_ThreePointPercentage_pg', 'TwoPointPercentage_pg', 'Blocks_pg', 'PersonalFouls_pg', 'def_BoxPlusMinus_pg', 'def_f_STLRank3', 'OffensiveRebounds_pg', 'def_FreeThrowPercentage_pg', 'def_OffensiveRebounds_pg', 'def_DefensiveRebounds_pg', 'def_f_PFRank3', 'def_f_TOVRank3', 'def_f_BLKRank3', 'f_FT%Rank3', 'def_MinutesPlayed_pg', 'def_f_ORBRank3', 'BPM_pg3', 'def_f_FT%Rank3', 'Steals_pg', 'def_Assists_pg']
# ['models/LGBM_models/F_model_20feats.pkl']

# %%
# Using Top 20 Features, Find Top 10 Features
model.fit(X_train[attr20], Y_train)
dset = pd.DataFrame({'attr':X_train[attr20].columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr10 = dset['attr'][0:10].tolist()

# hyperparameter tuning for 10 features
best_params_10 = hyperparameter_tuning(attr10)

""" MODEL SELECTION (10 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_10)
"""                 """

#print top10 features
print('T10 features', attr10, '\n')

# Fit model, make predictions with t10 features
model.fit(X_train[attr10], Y_train)
preds10 = model.predict(X_test[attr10])

# add model performance to pdf dataframe
pdf['Pred_F_DKPts_10'] = preds10
pdf['Predicted10Rank'] = pdf.groupby(['Season','Date'])['Pred_F_DKPts_10'].rank(method='min', ascending = False)

# save the model to disk
filename = 'models/LGBM_models/F_model_10feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.451 total time=  10.7s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.481 total time=  10.9s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.453 total time=  10.7s
# [CV 4/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.416 total time=  10.7s
# [CV 5/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.448 total time=  10.7s
# [CV 1/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.143 total time=  15.6s
# [CV 2/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.171 total time=  15.6s
# [CV 3/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.161 total time=  15.6s
# [CV 4/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.114 total time=  15.6s
# [CV 5/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.134 total time=  15.6s
# [CV 1/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.874 total time=  20.8s
# [CV 2/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.928 total time=  20.9s
# [CV 3/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.884 total time=  20.4s
# [CV 4/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.812 total time=  21.1s
# [CV 5/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.854 total time=  20.8s
# [CV 1/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.566 total time=  10.5s
# [CV 2/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.598 total time=  10.6s
# [CV 3/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.554 total time=  10.5s
# [CV 4/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.539 total time=  10.5s
# [CV 5/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.519 total time=  10.5s
# [CV 1/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.307 total time=  15.3s
# [CV 2/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.339 total time=  15.4s
# [CV 3/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.294 total time=  15.2s
# [CV 4/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.274 total time=  15.2s
# [CV 5/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.286 total time=  15.2s
# [CV 1/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.077 total time=  20.5s
# [CV 2/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.081 total time=  20.4s
# [CV 3/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.075 total time=  20.5s
# [CV 4/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.025 total time=  20.8s
# [CV 5/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.067 total time=  20.6s
# [CV 1/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.444 total time=  10.8s
# [CV 2/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.479 total time=  10.7s
# [CV 3/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.451 total time=  10.7s
# [CV 4/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.439 total time=  10.6s
# [CV 5/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.436 total time=  10.7s
# [CV 1/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.160 total time=  15.6s
# [CV 2/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.170 total time=  15.6s
# [CV 3/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.150 total time=  15.6s
# [CV 4/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.120 total time=  15.7s
# [CV 5/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.142 total time=  15.6s
# [CV 1/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.892 total time=  20.9s
# [CV 2/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.920 total time=  20.8s
# [CV 3/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.910 total time=  20.8s
# [CV 4/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.837 total time=  21.0s
# [CV 5/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.861 total time=  20.9s
# [CV 1/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.581 total time=  10.5s
# [CV 2/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.590 total time=  10.5s
# [CV 3/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.573 total time=  10.5s
# [CV 4/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.540 total time=  10.5s
# [CV 5/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.536 total time=  10.5s
# [CV 1/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.312 total time=  15.3s
# [CV 2/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.347 total time=  15.3s
# [CV 3/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.302 total time=  15.4s
# [CV 4/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.263 total time=  15.3s
# [CV 5/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.296 total time=  15.2s
# [CV 1/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.066 total time=  20.4s
# [CV 2/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.093 total time=  20.4s
# [CV 3/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.079 total time=  20.5s
# [CV 4/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.031 total time=  20.5s
# [CV 5/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.082 total time=  20.4s
# [CV 1/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.451 total time=  10.8s
# [CV 2/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.481 total time=  10.7s
# [CV 3/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.453 total time=  10.9s
# [CV 4/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.416 total time=  10.8s
# [CV 5/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.449 total time=  10.6s
# [CV 1/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.143 total time=  15.6s
# [CV 2/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.171 total time=  15.6s
# [CV 3/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.161 total time=  15.6s
# [CV 4/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.114 total time=  15.6s
# [CV 5/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.134 total time=  15.6s
# [CV 1/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.885 total time=  20.9s
# [CV 2/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.928 total time=  20.9s
# [CV 3/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.884 total time=  20.7s
# [CV 4/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.812 total time=  20.9s
# [CV 5/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.869 total time=  20.9s
# [CV 1/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.566 total time=  10.8s
# [CV 2/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.598 total time=  10.6s
# [CV 3/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.554 total time=  10.6s
# [CV 4/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.539 total time=  10.6s
# [CV 5/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.519 total time=  10.5s
# [CV 1/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.311 total time=  15.3s
# [CV 2/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.340 total time=  15.3s
# [CV 3/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.294 total time=  15.3s
# [CV 4/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.287 total time=  15.3s
# [CV 5/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.286 total time=  15.3s
# [CV 1/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.077 total time=  20.5s
# [CV 2/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.081 total time=  20.6s
# [CV 3/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.075 total time=  20.4s
# [CV 4/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.025 total time=  20.5s
# [CV 5/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.067 total time=  20.5s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -6.87058507264525
#  MAE: 6.707265
# T10 features ['BPM_pg3', 'TwoPointPercentage_pg', 'PersonalFouls_pg', 'OffensiveRebounds_pg', 'Steals_pg', 'Blocks_pg', 'def_f_BLKRank3', 'def_f_ORBRank3', 'def_f_TOVRank3', 'def_f_STLRank3']
# ['models/LGBM_models/F_model_10feats.pkl']

# %%
# write predictions to csv
pdf.to_csv(etl_dir + 'f_predictions_lgbm_50_30_20_15_10.csv')

# create df to summarize results

feature_sets = ['all', '50', '30', '20', '10']

mae_values = [
    "{:.2f}".format(mean_absolute_error(Y_test, preds_all)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds50)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds30)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds20)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds10))
]

results_df = pd.DataFrame({'Features' : feature_sets, 'MAE' : mae_values})

results_df.style.hide_index()
display(results_df)
# Out:
#   Features   MAE
# 0      all  5.14
# 1       50  5.54
# 2       30  5.95
# 3       20  6.28
# 4       10  6.71

# %%
pdf.sort_values(by = ['Date', 'Act_F_DKPts'], ascending = [True, False]).head(n=10)
# Out:
#        Season  Date Team Defense            Player  Act_F_DKPtsRank  \
# 24645    2012     0  CLE     WAS  Tristan Thompson             10.0
# 2124     2012     0  DAL     LAL       Elton Brand             13.0
# 27911    2012     0  DAL     LAL       Elton Brand             13.0
# 2955     2012     0  BOS     MIA      Brandon Bass             15.0
# 21755    2012     0  DAL     LAL    Brandan Wright             18.0
# 40267    2012     0  LAL     DAL       Kobe Bryant             21.0
# 9370     2012     0  MIA     BOS     Rashard Lewis             25.0
# 22673    2012     0  DAL     LAL       Jae Crowder             28.0
# 29657    2012     0  LAL     DAL    Antawn Jamison             29.0
# 37554    2012     0  CLE     WAS      Tyler Zeller             32.0
#
#        Act_F_DKPts  Pred_F_DKPts_all  PredictedallRank  Pred_F_DKPts_50  \
# 24645         32.5         29.404101               3.0        27.779141
# 2124          30.2         13.577620              11.0        17.665108
# 27911         30.2         13.577620              11.0        17.665108
# 2955          28.7         30.727116               2.0        25.401082
# 21755         26.0         24.341066               5.0        25.610543
# 40267         24.2         21.289287               7.0        23.001088
# 9370          20.5         24.817483               4.0        18.478969
# 22673         17.6         20.470319               9.0        17.147059
# 29657         17.0         35.932099               1.0        29.266876
# 37554         13.4         17.235267              10.0        16.501248
#
#        Predicted50Rank  Pred_F_DKPts_30  Predicted30Rank  Pred_F_DKPts_20  \
# 24645              2.0        27.081601              3.0        30.290438
# 2124               8.0        13.984526             11.0        15.180621
# 27911              8.0        13.984526             11.0        15.180621
# 2955               4.0        27.268070              2.0        28.254452
# 21755              3.0        24.996318              4.0        21.623814
# 40267              6.0        21.497278              7.0        23.043488
# 9370               7.0        23.070530              6.0        20.201218
# 22673             10.0        18.225580              8.0        20.202886
# 29657              1.0        32.762857              1.0        33.664212
# 37554             12.0        14.467916             10.0        17.908913
#
#        Predicted20Rank  Pred_F_DKPts_10  Predicted10Rank
# 24645              2.0        31.858550              1.0
# 2124              10.0        16.691359              8.0
# 27911             10.0        16.691359              8.0
# 2955               3.0        25.225692              2.0
# 21755              5.0        14.921484             10.0
# 40267              4.0        17.791553              7.0
# 9370               7.0        14.426824             12.0
# 22673              6.0        19.496967              5.0
# 29657              1.0        18.862694              6.0
# 37554              8.0        19.973734              4.0

# %% [markdown]
# ## Center Model

# %%
"""
"""

import os
import joblib
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from lightgbm import LGBMRegressor
import xgboost as xgb
from sklearn.metrics import mean_absolute_error

from sklearn.feature_selection import RFE

working_directory = 'D:/machine_learning/DFS/NBA/NBA_moredata'
os.chdir(working_directory)
data_dir = 'Data/'
etl_dir = 'Data/ETL/'

player_stats = pd.read_csv(data_dir + 'player_stats_all.csv', index_col = 0)
c_vs = pd.read_csv(etl_dir + 'c_stats.csv', index_col = 0)

c_vs = c_vs.rename(columns={'Opp':'Defense', 'Team_x' : 'Team'})

print(c_vs.columns.tolist())

#Grab Only Necessary Columns & Filter Only To C Data
c_act_stats = player_stats[(player_stats['Pos.']=='C') | (player_stats['Pos.']=='C-F') | (player_stats['Pos.']=='F-C')].copy().reset_index(drop=True)

c_act_stats = c_act_stats.fillna(0)

c_act_stats.drop(list(set(c_act_stats.columns) - set(c_vs)), axis = 1, inplace = True)

#Calculate The Draftkings Points for each player on each date
c_act_stats['Act_C_DKPts'] = (c_act_stats['3P'] * 1 + c_act_stats['AST'] * 1.5 +\
                           c_act_stats['BLK'] * 3 + c_act_stats['FG'] * 2 +\
                           c_act_stats['FT'] * 1 + c_act_stats['TRB'] * 1.2 +\
                           c_act_stats['STL'] * 3 + c_act_stats['TOV'] * -1)

#G DK PTS Rank For The Given Season & Date Pair
c_act_stats['Act_C_DKPtsRank'] = c_act_stats.groupby(['Season','Date'])['Act_C_DKPts'].rank(method='min', ascending = False)

#Columns We Want To Add To Dataset
keep_cols = ['Season','Date','Player','Act_C_DKPtsRank','Act_C_DKPts']

#Append Actual DK Pts Rank & DK Pts
c_vs_act = pd.merge(c_vs, c_act_stats[keep_cols], how = 'left', on = ['Season','Date','Player'])
c_vs_act = c_vs_act[c_vs_act['Act_C_DKPts']>0].reset_index(drop=True)

#Make sure we have no duplicated columns or infinity errors
c_vs_act = c_vs_act.loc[:,~c_vs_act.columns.duplicated()]
c_vs_act = c_vs_act.replace([np.inf, -np.inf], np.nan)
c_vs_act.to_csv(etl_dir + 'g_v_def_stats.csv')

#Columns We Can't Include In Our Features Datasets
dcols = ['Age',
         'at',
         'Result',
         'GS',
         'FG',
         'FGA',
         'FG%',
         '2P',
         '2PA',
         '2P%',
         '3P',
         '3PA',
         '3P%',
         'FT',
         'FTA',
         'FT%',
         'TS%',
         'ORB',
         'DRB',
         'TRB',
         'AST',
         'STL',
         'BLK',
         'TOV',
         'PF',
         'PTS',
         'GmSc',
         'BPM',
         'Pos.',
         'Month',
         'Year',
         'Team_y',
         'Act_C_DKPts',
         'EFF',
         'MP'
]


more_dcols = ['Season', 'Date', 'Team', 'Defense', 'Player', 'Act_C_DKPtsRank']

# c_vs_act.drop_duplicates(subset=['Player', 'Date'], keep='first', inplace = True, ignore_index = True)

X = c_vs_act.drop(dcols, axis = 1)
Y = c_vs_act['Act_C_DKPts']

from sklearn.model_selection import train_test_split

#Create Training and Testing DataSets
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.25, random_state=42)

X_train.reset_index(inplace = True, drop=True)
X_test.reset_index(inplace = True, drop=True)
Y_train.reset_index(inplace = True, drop=True)
Y_test.reset_index(inplace = True, drop=True)

print('Training set size:', len(X_train))
print('Testing set size:', len(X_test))

pred_df = pd.concat([X_test, Y_test], axis = 1)

X_train.drop(more_dcols, axis = 1, inplace = True)
X_test.drop(more_dcols, axis = 1, inplace = True)
# Out:
# ['Player', 'Date', 'Age', 'Team', 'at', 'Defense', 'Result', 'GS', 'MP', 'FG', 'FGA', 'FG%', '2P', '2PA', '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'TS%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', 'BPM', 'Pos.', 'EFF', 'Month', 'Year', 'Season', 'MP3', 'MP_pg3', 'FG3', 'FG_pg3', 'FGA3', 'FGA_pg3', 'FG%_pg3', '2P3', '2P_pg3', '2PA3', '2PA_pg3', '2P%_pg3', '3P3', '3P_pg3', '3PA3', '3PA_pg3', '3P%_pg3', 'FT3', 'FT_pg3', 'FTA3', 'FTA_pg3', 'FT%3', 'FT%_pg3', 'TS%_pg3', 'ORB3', 'ORB_pg3', 'DRB3', 'DRB_pg3', 'TRB3', 'TRB_pg3', 'AST3', 'AST_pg3', 'STL3', 'STL_pg3', 'BLK3', 'BLK_pg3', 'TOV3', 'TOV_pg3', 'PF3', 'PF_pg3', 'PTS3', 'PTS_pg3', 'GmSc3', 'GmSc_pg3', 'BPM_pg3', 'EFF3', 'EFF_pg3', 'c_MP3Rank3', 'c_FG3Rank3', 'c_FGARank3', 'c_FG%Rank3', 'c_2PRank3', 'c_2PARank3', 'c_2P%Rank3', 'c_3PRank3', 'c_3PARank3', 'c_3P%Rank3', 'c_FTRank3', 'c_FTARank3', 'c_FT%Rank3', 'c_TS%Rank3', 'c_ORBRank3', 'c_DRBRank3', 'c_TRBRank3', 'c_ASTRank3', 'c_STLRank3', 'c_BLKRank3', 'c_TOVRank3', 'c_PFRank3', 'c_PTSRank3', 'c_GMScRank3', 'c_BPMRank3', 'c_EFFRank3', 'c_DKPts3', 'c_DKPtsRank3', 'MinutesPlayed', 'MinutesPlayed_pg', 'FieldGoals', 'FieldGoals_pg', 'FieldGoalAttempts', 'FieldGoalAttempts_pg', 'FieldGoalPercentage_pg', 'TwoPointers', 'TwoPointers_pg', 'TwoPointAttempts', 'TwoPointAttempts_pg', 'TwoPointPercentage_pg', 'ThreePointers', 'ThreePointers_pg', 'ThreePointAttempts', 'ThreePointAttempts_pg', 'ThreePointPercentage_pg', 'FreeThrows', 'FreeThrows_pg', 'FreeThrowAttempts', 'FreeThrowAttempts_pg', 'FreeThrowPercentage_pg', 'TrueShootingPercentage_pg', 'OffensiveRebounds', 'OffensiveRebounds_pg', 'DefensiveRebounds', 'DefensiveRebounds_pg', 'TotalRebounds', 'TotalRebounds_pg', 'Assists', 'Assists_pg', 'Steals', 'Steals_pg', 'Blocks', 'Blocks_pg', 'Turnovers', 'Turnovers_pg', 'PersonalFouls', 'PersonalFouls_pg', 'Points', 'Points_pg', 'GameScore_pg', 'BoxPlusMinus_pg', 'Efficiency_pg', 'c_DKPts_szn', 'c_DKPtsRank_szn', 'def_MP3', 'def_MP_pg3', 'def_FG3', 'def_FG_pg3', 'def_FGA3', 'def_FGA_pg3', 'def_FG%_pg3', 'def_2P3', 'def_2P_pg3', 'def_2PA3', 'def_2PA_pg3', 'def_2P%_pg3', 'def_3P3', 'def_3P_pg3', 'def_3PA3', 'def_3PA_pg3', 'def_3P%_pg3', 'def_FT3', 'def_FT_pg3', 'def_FTA3', 'def_FTA_pg3', 'def_FT%_pg3', 'def_TS%_pg3', 'def_ORB3', 'def_ORB_pg3', 'def_DRB3', 'def_DRB_pg3', 'def_TRB3', 'def_TRB_pg3', 'def_AST3', 'def_AST_pg3', 'def_STL3', 'def_STL_pg3', 'def_BLK3', 'def_BLK_pg3', 'def_TOV3', 'def_TOV_pg3', 'def_PF3', 'def_PF_pg3', 'def_PTS3', 'def_PTS_pg3', 'def_GmSc3', 'def_GmSc_pg3', 'def_BPM_pg3', 'def_EFF3', 'def_EFF_pg3', 'def_c_MP3Rank3', 'def_c_FG3Rank3', 'def_c_FGARank3', 'def_c_FG%Rank3', 'def_c_2PRank3', 'def_c_2PARank3', 'def_c_2P%Rank3', 'def_c_3PRank3', 'def_c_3PARank3', 'def_c_3P%Rank3', 'def_c_FTRank3', 'def_c_FTARank3', 'def_c_FT%Rank3', 'def_c_TS%Rank3', 'def_c_ORBRank3', 'def_c_DRBRank3', 'def_c_TRBRank3', 'def_c_ASTRank3', 'def_c_STLRank3', 'def_c_BLKRank3', 'def_c_TOVRank3', 'def_c_PFRank3', 'def_c_PTSRank3', 'def_c_GMScRank3', 'def_c_BPMRank3', 'def_c_EFFRank3', 'def_c_DKPts3', 'def_c_DKPtsRank3', 'def_MinutesPlayed', 'def_MinutesPlayed_pg', 'def_FieldGoals', 'def_FieldGoals_pg', 'def_FieldGoalAttempts', 'def_FieldGoalAttempts_pg', 'def_FieldGoalPercentage_pg', 'def_TwoPointers', 'def_TwoPointers_pg', 'def_TwoPointAttempts', 'def_TwoPointAttempts_pg', 'def_TwoPointPercentage_pg', 'def_ThreePointers', 'def_ThreePointers_pg', 'def_ThreePointAttempts', 'def_ThreePointAttempts_pg', 'def_ThreePointPercentage_pg', 'def_FreeThrows', 'def_FreeThrows_pg', 'def_FreeThrowAttempts', 'def_FreeThrowAttempts_pg', 'def_FreeThrowPercentage_pg', 'def_TrueShootingPercentage_pg', 'def_OffensiveRebounds', 'def_OffensiveRebounds_pg', 'def_DefensiveRebounds', 'def_DefensiveRebounds_pg', 'def_TotalRebounds', 'def_TotalRebounds_pg', 'def_Assists', 'def_Assists_pg', 'def_Steals', 'def_Steals_pg', 'def_Blocks', 'def_Blocks_pg', 'def_Turnovers', 'def_Turnovers_pg', 'def_PersonalFouls', 'def_PersonalFouls_pg', 'def_Point ...
# Training set size: 60975
# Testing set size: 20326
# C:\Users\Greg\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# dump non-scaled train df for external scaling to work
filename = 'scalers/c_X_train.pkl'
joblib.dump(X_train, filename)

# Scaling
from sklearn.preprocessing import StandardScaler
c_scaler = StandardScaler().fit(X_train)
X_train = pd.DataFrame(c_scaler.transform(X_train), columns = X_train.columns)
X_test = pd.DataFrame(c_scaler.transform(X_test), columns = X_test.columns)
filename = 'scalers/c_scaler.pkl'
joblib.dump(c_scaler, filename)

print('\nNum Possible Features:',len(X_train.columns.tolist()))
# Out:
# Num Possible Features: 241

# %%
# hyperparameter tuning function
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

def hyperparameter_tuning(feat_set):
    # define model for param tuning
    model = LGBMRegressor()

    # define param grid
    param_grid = {
        'random_state' : [1],
        'n_jobs' : [-1],
        'n_estimators' : [1000],
        'learning_rate': [0.1],
        'num_leaves': [62, 93, 127],
        'max_depth' :[-1, 20, 40],
        'min_child_samples' : [20, 80],
        'max_bin' : [63],
        'device' : ['gpu']
    }

    gsearch = GridSearchCV(model, param_grid, verbose = 10, scoring = 'neg_mean_absolute_error') 

    lgb_model = gsearch.fit(X_train[feat_set], Y_train)
    print('best params')
    print(gsearch.best_params_, gsearch.best_score_)
    preds_lgb_model = lgb_model.predict(X_test[feat_set])
    mae_lgb = mean_absolute_error(Y_test, preds_lgb_model)
    print(" MAE: %f" % (mae_lgb ))
    return lgb_model.best_params_

# %%
# hyperparameter tuning for all features
best_params_all = hyperparameter_tuning(X_train.columns.tolist())

""" MODEL SELECTION (ALL FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_all)
"""                 """

#print possible features
print('possible features:', X_train.columns.tolist(), '\n')

# Fit model, make predictions with all features
model.fit(X_train, Y_train)

preds_all = model.predict(X_test)

pdf = pred_df[['Season','Date','Team','Defense','Player','Act_C_DKPtsRank','Act_C_DKPts']].copy()
pdf['Pred_C_DKPts_all'] = preds_all
pdf['PredictedallRank'] = pdf.groupby(['Season','Date'])['Pred_C_DKPts_all'].rank(method='min', ascending = False)
temp_df_all = pdf[pdf['PredictedallRank']<=5]

# save the initial model to disk
filename = 'models/LGBM_models/C_model_allfeats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.223 total time=  16.3s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.131 total time=  13.3s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.219 total time=  13.4s
# [CV 4/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 4/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.135 total time=  13.5s
# [CV 5/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 5/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.060 total time=  13.2s
# [CV 1/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 1/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.951 total time=  19.2s
# [CV 2/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 2/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.781 total time=  18.9s
# [CV 3/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 3/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.875 total time=  19.8s
# [CV 4/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 4/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.826 total time=  19.4s
# [CV 5/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 5/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.741 total time=  19.0s
# [CV 1/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 1/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.722 total time=  25.0s
# [CV 2/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 2/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.606 total time=  25.2s
# [CV 3/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 3/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.671 total time=  25.2s
# [CV 4/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 4/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.604 total time=  25.5s
# [CV 5/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [CV 5/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.532 total time=  25.4s
# [CV 1/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 1/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.326 total time=  12.2s
# [CV 2/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 2/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.204 total time=  12.4s
# [CV 3/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 3/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.285 total time=  12.3s
# [CV 4/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 4/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.232 total time=  12.7s
# [CV 5/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 5/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.143 total time=  12.3s
# [CV 1/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 1/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.987 total time=  18.1s
# [CV 2/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 2/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.906 total time=  18.2s
# [CV 3/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 3/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.942 total time=  18.0s
# [CV 4/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 4/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.880 total time=  17.8s
# [CV 5/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 5/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-5.787 total time=  17.6s
# [CV 1/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 1/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.779 total time=  24.3s
# [CV 2/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 2/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5
min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_data_in_leaf=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.586 total time=  24.1s
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 20, 'min_data_in_leaf': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -5.6187139917891304
#  MAE: 5.263495
# possible features: ['MP3', 'MP_pg3', 'FG3', 'FG_pg3', 'FGA3', 'FGA_pg3', 'FG%_pg3', '2P3', '2P_pg3', '2PA3', '2PA_pg3', '2P%_pg3', '3P3', '3P_pg3', '3PA3', '3PA_pg3', '3P%_pg3', 'FT3', 'FT_pg3', 'FTA3', 'FTA_pg3', 'FT%3', 'FT%_pg3', 'TS%_pg3', 'ORB3', 'ORB_pg3', 'DRB3', 'DRB_pg3', 'TRB3', 'TRB_pg3', 'AST3', 'AST_pg3', 'STL3', 'STL_pg3', 'BLK3', 'BLK_pg3', 'TOV3', 'TOV_pg3', 'PF3', 'PF_pg3', 'PTS3', 'PTS_pg3', 'GmSc3', 'GmSc_pg3', 'BPM_pg3', 'EFF3', 'EFF_pg3', 'c_MP3Rank3', 'c_FG3Rank3', 'c_FGARank3', 'c_FG%Rank3', 'c_2PRank3', 'c_2PARank3', 'c_2P%Rank3', 'c_3PRank3', 'c_3PARank3', 'c_3P%Rank3', 'c_FTRank3', 'c_FTARank3', 'c_FT%Rank3', 'c_TS%Rank3', 'c_ORBRank3', 'c_DRBRank3', 'c_TRBRank3', 'c_ASTRank3', 'c_STLRank3', 'c_BLKRank3', 'c_TOVRank3', 'c_PFRank3', 'c_PTSRank3', 'c_GMScRank3', 'c_BPMRank3', 'c_EFFRank3', 'c_DKPts3', 'c_DKPtsRank3', 'MinutesPlayed', 'MinutesPlayed_pg', 'FieldGoals', 'FieldGoals_pg', 'FieldGoalAttempts', 'FieldGoalAttempts_pg', 'FieldGoalPercentage_pg', 'TwoPointers', 'TwoPointers_pg', 'TwoPointAttempts', 'TwoPointAttempts_pg', 'TwoPointPercentage_pg', 'ThreePointers', 'ThreePointers_pg', 'ThreePointAttempts', 'ThreePointAttempts_pg', 'ThreePointPercentage_pg', 'FreeThrows', 'FreeThrows_pg', 'FreeThrowAttempts', 'FreeThrowAttempts_pg', 'FreeThrowPercentage_pg', 'TrueShootingPercentage_pg', 'OffensiveRebounds', 'OffensiveRebounds_pg', 'DefensiveRebounds', 'DefensiveRebounds_pg', 'TotalRebounds', 'TotalRebounds_pg', 'Assists', 'Assists_pg', 'Steals', 'Steals_pg', 'Blocks', 'Blocks_pg', 'Turnovers', 'Turnovers_pg', 'PersonalFouls', 'PersonalFouls_pg', 'Points', 'Points_pg', 'GameScore_pg', 'BoxPlusMinus_pg', 'Efficiency_pg', 'c_DKPts_szn', 'c_DKPtsRank_szn', 'def_MP3', 'def_MP_pg3', 'def_FG3', 'def_FG_pg3', 'def_FGA3', 'def_FGA_pg3', 'def_FG%_pg3', 'def_2P3', 'def_2P_pg3', 'def_2PA3', 'def_2PA_pg3', 'def_2P%_pg3', 'def_3P3', 'def_3P_pg3', 'def_3PA3', 'def_3PA_pg3', 'def_3P%_pg3', 'def_FT3', 'def_FT_pg3', 'def_FTA3', 'def_FTA_pg3', 'def_FT%_pg3', 'def_TS%_pg3', 'def_ORB3', 'def_ORB_pg3', 'def_DRB3', 'def_DRB_pg3', 'def_TRB3', 'def_TRB_pg3', 'def_AST3', 'def_AST_pg3', 'def_STL3', 'def_STL_pg3', 'def_BLK3', 'def_BLK_pg3', 'def_TOV3', 'def_TOV_pg3', 'def_PF3', 'def_PF_pg3', 'def_PTS3', 'def_PTS_pg3', 'def_GmSc3', 'def_GmSc_pg3', 'def_BPM_pg3', 'def_EFF3', 'def_EFF_pg3', 'def_c_MP3Rank3', 'def_c_FG3Rank3', 'def_c_FGARank3', 'def_c_FG%Rank3', 'def_c_2PRank3', 'def_c_2PARank3', 'def_c_2P%Rank3', 'def_c_3PRank3', 'def_c_3PARank3', 'def_c_3P%Rank3', 'def_c_FTRank3', 'def_c_FTARank3', 'def_c_FT%Rank3', 'def_c_TS%Rank3', 'def_c_ORBRank3', 'def_c_DRBRank3', 'def_c_TRBRank3', 'def_c_ASTRank3', 'def_c_STLRank3', 'def_c_BLKRank3', 'def_c_TOVRank3', 'def_c_PFRank3', 'def_c_PTSRank3', 'def_c_GMScRank3', 'def_c_BPMRank3', 'def_c_EFFRank3', 'def_c_DKPts3', 'def_c_DKPtsRank3', 'def_MinutesPlayed', 'def_MinutesPlayed_pg', 'def_FieldGoals', 'def_FieldGoals_pg', 'def_FieldGoalAttempts', 'def_FieldGoalAttempts_pg', 'def_FieldGoalPercentage_pg', 'def_TwoPointers', 'def_TwoPointers_pg', 'def_TwoPointAttempts', 'def_TwoPointAttempts_pg', 'def_TwoPointPercentage_pg', 'def_ThreePointers', 'def_ThreePointers_pg', 'def_ThreePointAttempts', 'def_ThreePointAttempts_pg', 'def_ThreePointPercentage_pg', 'def_FreeThrows', 'def_FreeThrows_pg', 'def_FreeThrowAttempts', 'def_FreeThrowAttempts_pg', 'def_FreeThrowPercentage_pg', 'def_TrueShootingPercentage_pg', 'def_OffensiveRebounds', 'def_OffensiveRebounds_pg', 'def_DefensiveRebounds', 'def_DefensiveRebounds_pg', 'def_TotalRebounds', 'def_TotalRebounds_pg', 'def_Assists', 'def_Assists_pg', 'def_Steals', 'def_Steals_pg', 'def_Blocks', 'def_Blocks_pg', 'def_Turnovers', 'def_Turnovers_pg', 'def_PersonalFouls', 'def_PersonalFouls_pg', 'def_Points', 'def_Points_pg', 'def_GameScore_pg', 'def_BoxPlusMinus_pg', 'def_Efficiency_pg', 'def_c_DKPts_szn', 'def_c_DKPtsRank_szn']
#
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# ['models/LGBM_models/C_model_allfeats.pkl']

# %%
# get top 50 features
dset = pd.DataFrame({'attr':X_train.columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr50 = dset['attr'][0:50].tolist()

# hyperparameter tuning for 50 features
best_params_50 = hyperparameter_tuning(attr50)

""" MODEL SELECTION (50 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_50)
"""                 """

#print top50 features
print('T50 features', attr50, '\n')

# Fit model, make predictions with t50 features
model.fit(X_train[attr50], Y_train)
preds50 = model.predict(X_test[attr50])

# add model performance to pdf dataframe
pdf['Pred_C_DKPts_50'] = preds50
pdf['Predicted50Rank'] = pdf.groupby(['Season','Date'])['Pred_C_DKPts_50'].rank(method='min', ascending = False)

# save the model to disk
filename = 'models/LGBM_models/C_model_50feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.609 total time=  11.4s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.565 total time=  11.2s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.631 total time=  11.4s
# [CV 4/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.532 total time=  11.0s
# [CV 5/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.435 total time=  14.2s
# [CV 1/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.269 total time=  19.5s
# [CV 2/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.194 total time=  16.2s
# [CV 3/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.237 total time=  16.1s
# [CV 4/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.168 total time=  16.1s
# [CV 5/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.091 total time=  15.9s
# [CV 1/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.063 total time=  22.2s
# [CV 2/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.979 total time=  22.1s
# [CV 3/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.989 total time=  21.3s
# [CV 4/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.898 total time=  22.5s
# [CV 5/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.819 total time=  21.6s
# [CV 1/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.705 total time=  11.3s
# [CV 2/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.678 total time=  10.4s
# [CV 3/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.714 total time=  10.4s
# [CV 4/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.630 total time=  10.4s
# [CV 5/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.492 total time=  10.5s
# [CV 1/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.387 total time=  15.4s
# [CV 2/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.359 total time=  15.9s
# [CV 3/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.332 total time=  15.6s
# [CV 4/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.209 total time=  15.2s
# [CV 5/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.147 total time=  15.4s
# [CV 1/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.106 total time=  20.8s
# [CV 2/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.033 total time=  21.0s
# [CV 3/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.077 total time=  20.7s
# [CV 4/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.998 total time=  20.8s
# [CV 5/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.895 total time=  21.6s
# [CV 1/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.649 total time=  11.0s
# [CV 2/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.566 total time=  11.1s
# [CV 3/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.627 total time=  11.0s
# [CV 4/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.546 total time=  11.0s
# [CV 5/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.469 total time=  10.9s
# [CV 1/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.301 total time=  16.0s
# [CV 2/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.219 total time=  16.8s
# [CV 3/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.245 total time=  16.2s
# [CV 4/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.169 total time=  16.1s
# [CV 5/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.059 total time=  16.3s
# [CV 1/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.052 total time=  21.4s
# [CV 2/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.941 total time=  22.0s
# [CV 3/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.995 total time=  21.5s
# [CV 4/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.921 total time=  21.9s
# [CV 5/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.825 total time=  22.8s
# [CV 1/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.710 total time=  10.8s
# [CV 2/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.673 total time=  11.1s
# [CV 3/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.711 total time=  11.0s
# [CV 4/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.592 total time=  11.0s
# [CV 5/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.503 total time=  10.9s
# [CV 1/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.361 total time=  15.7s
# [CV 2/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.310 total time=  16.0s
# [CV 3/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.334 total time=  15.5s
# [CV 4/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.259 total time=  16.2s
# [CV 5/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.129 total time=  16.1s
# [CV 1/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.103 total time=  21.9s
# [CV 2/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.044 total time=  21.9s
# [CV 3/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.080 total time=  21.9s
# [CV 4/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.988 total time=  22.2s
# [CV 5/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.841 total time=  23.5s
# [CV 1/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.608 total time=  12.8s
# [CV 2/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.565 total time=  13.0s
# [CV 3/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.631 total time=  13.2s
# [CV 4/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.533 total time=  14.2s
# [CV 5/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.436 total time=  13.6s
# [CV 1/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.285 total time=  18.9s
# [CV 2/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.195 total time=  18.7s
# [CV 3/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.237 total time=  16.2s
# [CV 4/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.167 total time=  16.5s
# [CV 5/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.091 total time=  16.2s
# [CV 1/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.059 total time=  24.7s
# [CV 2/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.978 total time=  27.8s
# [CV 3/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.997 total time=  22.5s
# [CV 4/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.897 total time=  22.3s
# [CV 5/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.820 total time=  23.4s
# [CV 1/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.705 total time=  11.7s
# [CV 2/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.678 total time=  11.4s
# [CV 3/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.714 total time=  10.9s
# [CV 4/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.630 total time=  10.8s
# [CV 5/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.492 total time=  11.3s
# [CV 1/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.387 total time=  16.4s
# [CV 2/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.359 total time=  16.2s
# [CV 3/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.331 total time=  16.5s
# [CV 4/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.209 total time=  16.1s
# [CV 5/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.148 total time=  16.2s
# [CV 1/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.117 total time=  21.1s
# [CV 2/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.033 total time=  21.1s
# [CV 3/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.077 total time=  21.0s
# [CV 4/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.998 total time=  21.2s
# [CV 5/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-5.895 total time=  21.2s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 20, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -5.946768605167243
#  MAE: 5.593945
# T50 features ['def_BoxPlusMinus_pg', 'def_FreeThrowPercentage_pg', 'def_c_BLKRank3', 'def_PersonalFouls_pg', 'def_c_STLRank3', 'def_Steals_pg', 'def_Blocks_pg', 'Blocks_pg', 'def_c_ASTRank3', 'def_Turnovers_pg', 'def_BPM_pg3', 'BPM_pg3', 'def_OffensiveRebounds_pg', 'c_PFRank3', 'def_c_PFRank3', 'def_c_TOVRank3', 'def_c_ORBRank3', 'def_MinutesPlayed_pg', 'PersonalFouls_pg', 'c_BLKRank3', 'c_STLRank3', 'c_TOVRank3', 'def_Assists_pg', 'Steals_pg', 'BoxPlusMinus_pg', 'def_c_FT%Rank3', 'Blocks', 'def_TwoPointPercentage_pg', 'def_FieldGoalPercentage_pg', 'c_ASTRank3', 'def_DefensiveRebounds_pg', 'def_FreeThrowAttempts_pg', 'Assists_pg', 'def_TS%_pg3', 'def_FT%_pg3', 'OffensiveRebounds_pg', 'TrueShootingPercentage_pg', 'FT%_pg3', 'c_FT%Rank3', 'def_ThreePointPercentage_pg', 'c_ORBRank3', 'def_c_BPMRank3', 'Turnovers_pg', 'def_TrueShootingPercentage_pg', 'TS%_pg3', 'def_c_3PARank3', 'def_TwoPointAttempts_pg', 'def_c_FTARank3', 'def_FreeThrows_pg', 'def_c_3P%Rank3']
# ['models/LGBM_models/C_model_50feats.pkl']

# %%
# Using Top 50 Features, Find Top 30 Features
model.fit(X_train[attr50], Y_train)
dset = pd.DataFrame({'attr':X_train[attr50].columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr30 = dset['attr'][0:30].tolist()

# hyperparameter tuning for 30 features
best_params_30 = hyperparameter_tuning(attr30)

""" MODEL SELECTION (30 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_30)
"""                 """

#print top50 features
print('T30 features', attr30, '\n')

# Fit model, make predictions with t30 features
model.fit(X_train[attr30], Y_train)
preds30 = model.predict(X_test[attr30])

# add model performance to pdf dataframe
pdf['Pred_C_DKPts_30'] = preds30
pdf['Predicted30Rank'] = pdf.groupby(['Season','Date'])['Pred_C_DKPts_30'].rank(method='min', ascending = False)

# save the model to disk
filename = 'models/LGBM_models/C_model_30feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.890 total time=  10.7s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.802 total time=  11.3s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.820 total time=  10.8s
# [CV 4/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.763 total time=  10.8s
# [CV 5/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.688 total time=  11.1s
# [CV 1/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.531 total time=  16.2s
# [CV 2/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.419 total time=  15.9s
# [CV 3/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.461 total time=  15.8s
# [CV 4/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.373 total time=  16.1s
# [CV 5/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.297 total time=  16.0s
# [CV 1/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.222 total time=  22.6s
# [CV 2/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.150 total time=  21.8s
# [CV 3/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.188 total time=  22.1s
# [CV 4/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.093 total time=  21.5s
# [CV 5/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.054 total time=  22.0s
# [CV 1/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.966 total time=  10.7s
# [CV 2/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.888 total time=  10.7s
# [CV 3/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.949 total time=  10.6s
# [CV 4/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.857 total time=  10.6s
# [CV 5/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.800 total time=  10.4s
# [CV 1/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.609 total time=  15.5s
# [CV 2/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.545 total time=  16.9s
# [CV 3/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.588 total time=  15.7s
# [CV 4/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.498 total time=  15.6s
# [CV 5/5; 5/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 5/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.417 total time=  15.3s
# [CV 1/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.373 total time=  20.4s
# [CV 2/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.264 total time=  20.8s
# [CV 3/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.301 total time=  20.7s
# [CV 4/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.203 total time=  20.8s
# [CV 5/5; 6/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 6/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.108 total time=  20.9s
# [CV 1/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.859 total time=  11.1s
# [CV 2/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.831 total time=  11.0s
# [CV 3/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.821 total time=  10.9s
# [CV 4/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.790 total time=  10.8s
# [CV 5/5; 7/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 7/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.694 total time=  11.1s
# [CV 1/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.505 total time=  16.6s
# [CV 2/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.424 total time=  16.1s
# [CV 3/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.463 total time=  16.3s
# [CV 4/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.377 total time=  18.1s
# [CV 5/5; 8/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 8/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.309 total time=  16.3s
# [CV 1/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.264 total time=  21.8s
# [CV 2/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.153 total time=  21.3s
# [CV 3/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.186 total time=  21.3s
# [CV 4/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.118 total time=  22.0s
# [CV 5/5; 9/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 9/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.051 total time=  22.1s
# [CV 1/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.997 total time=  10.8s
# [CV 2/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.884 total time=  10.6s
# [CV 3/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.927 total time=  11.0s
# [CV 4/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.860 total time=  10.4s
# [CV 5/5; 10/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 10/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.779 total time=  10.5s
# [CV 1/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.610 total time=  15.5s
# [CV 2/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.543 total time=  15.7s
# [CV 3/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.573 total time=  15.7s
# [CV 4/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.472 total time=  15.7s
# [CV 5/5; 11/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 11/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.399 total time=  15.5s
# [CV 1/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.361 total time=  20.9s
# [CV 2/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.226 total time=  20.5s
# [CV 3/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.320 total time=  21.0s
# [CV 4/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.188 total time=  20.5s
# [CV 5/5; 12/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 12/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=20, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.129 total time=  20.7s
# [CV 1/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.891 total time=  10.9s
# [CV 2/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.802 total time=  11.5s
# [CV 3/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.820 total time=  11.2s
# [CV 4/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.762 total time=  11.1s
# [CV 5/5; 13/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 13/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.687 total time=  10.9s
# [CV 1/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.531 total time=  16.1s
# [CV 2/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.420 total time=  16.2s
# [CV 3/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.460 total time=  15.9s
# [CV 4/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.373 total time=  15.9s
# [CV 5/5; 14/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 14/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.297 total time=  16.9s
# [CV 1/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.223 total time=  22.7s
# [CV 2/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.149 total time=  22.9s
# [CV 3/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.188 total time=  22.1s
# [CV 4/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.093 total time=  21.9s
# [CV 5/5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.054 total time=  22.0s
# [CV 1/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.966 total time=  10.8s
# [CV 2/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.888 total time=  10.8s
# [CV 3/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.949 total time=  11.0s
# [CV 4/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.858 total time=  11.0s
# [CV 5/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-6.780 total time=  11.3s
# [CV 1/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.609 total time=  15.9s
# [CV 2/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.545 total time=  15.7s
# [CV 3/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.588 total time=  16.1s
# [CV 4/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.498 total time=  15.8s
# [CV 5/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.417 total time=  16.2s
# [CV 1/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.374 total time=  21.2s
# [CV 2/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.264 total time=  21.4s
# [CV 3/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.302 total time=  22.4s
# [CV 4/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.203 total time=  21.2s
# [CV 5/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.108 total time=  21.9s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 40, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -6.141405788678857
#  MAE: 5.812333
# T30 features ['Blocks', 'TS%_pg3', 'def_c_ORBRank3', 'OffensiveRebounds_pg', 'def_TS%_pg3', 'def_PersonalFouls_pg', 'def_c_PFRank3', 'def_Turnovers_pg', 'def_OffensiveRebounds_pg', 'def_MinutesPlayed_pg', 'BPM_pg3', 'def_DefensiveRebounds_pg', 'Assists_pg', 'def_TwoPointAttempts_pg', 'def_c_TOVRank3', 'def_c_BLKRank3', 'def_Blocks_pg', 'PersonalFouls_pg', 'c_PFRank3', 'c_BLKRank3', 'def_c_ASTRank3', 'def_c_STLRank3', 'def_BoxPlusMinus_pg', 'def_FreeThrowPercentage_pg', 'Blocks_pg', 'Steals_pg', 'def_Steals_pg', 'TrueShootingPercentage_pg', 'c_STLRank3', 'def_BPM_pg3']
# ['models/LGBM_models/C_model_30feats.pkl']

# %%
# Using Top 30 Features, Find Top 20 Features
model.fit(X_train[attr30], Y_train)
dset = pd.DataFrame({'attr':X_train[attr30].columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr20 = dset['attr'][0:20].tolist()

# hyperparameter tuning for 20 features
best_params_20 = hyperparameter_tuning(attr20)

""" MODEL SELECTION (20 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_20)
"""                 """

#print top20 features
print('T20 features', attr20, '\n')

# Fit model, make predictions with t20 features
model.fit(X_train[attr20], Y_train)
preds20 = model.predict(X_test[attr20])

# add model performance to pdf dataframe
pdf['Pred_C_DKPts_20'] = preds20
pdf['Predicted20Rank'] = pdf.groupby(['Season','Date'])['Pred_C_DKPts_20'].rank(method='min', ascending = False)

# save the model to disk
filename = 'models/LGBM_models/C_model_20feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7
5; 15/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 15/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.297 total time=  22.0s
# [CV 1/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.269 total time=  10.7s
# [CV 2/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.158 total time=  10.7s
# [CV 3/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.218 total time=  11.1s
# [CV 4/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.135 total time=  10.8s
# [CV 5/5; 16/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 16/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.103 total time=  10.6s
# [CV 1/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.859 total time=  15.5s
# [CV 2/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.796 total time=  15.6s
# [CV 3/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.850 total time=  15.6s
# [CV 4/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.783 total time=  15.6s
# [CV 5/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-6.766 total time=  15.4s
# [CV 1/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.632 total time=  20.8s
# [CV 2/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.492 total time=  20.6s
# [CV 3/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.544 total time=  20.7s
# [CV 4/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.533 total time=  20.4s
# [CV 5/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.475 total time=  20.3s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 20, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -6.378071480711947
#  MAE: 6.140058
# T20 features ['TS%_pg3', 'OffensiveRebounds_pg', 'Assists_pg', 'TrueShootingPercentage_pg', 'BPM_pg3', 'c_PFRank3', 'def_PersonalFouls_pg', 'Blocks', 'def_FreeThrowPercentage_pg', 'def_c_ORBRank3', 'def_Blocks_pg', 'def_BPM_pg3', 'def_TS%_pg3', 'PersonalFouls_pg', 'def_DefensiveRebounds_pg', 'def_BoxPlusMinus_pg', 'def_TwoPointAttempts_pg', 'def_Turnovers_pg', 'def_c_PFRank3', 'def_Steals_pg']
# ['models/LGBM_models/C_model_20feats.pkl']

# %%
# Using Top 20 Features, Find Top 10 Features
model.fit(X_train[attr20], Y_train)
dset = pd.DataFrame({'attr':X_train[attr20].columns.tolist(),'importance':model.feature_importances_}).sort_values(by='importance', ascending=False).reset_index(drop=True)
attr10 = dset['attr'][0:10].tolist()

# hyperparameter tuning for 10 features
best_params_10 = hyperparameter_tuning(attr10)

""" MODEL SELECTION (10 FEATS)"""
# all feature model with tuned hyperparameters
model = LGBMRegressor(**best_params_10)
"""                 """

#print top10 features
print('T10 features', attr10, '\n')

# Fit model, make predictions with t10 features
model.fit(X_train[attr10], Y_train)
preds10 = model.predict(X_test[attr10])

# add model performance to pdf dataframe
pdf['Pred_C_DKPts_10'] = preds10
pdf['Predicted10Rank'] = pdf.groupby(['Season','Date'])['Pred_C_DKPts_10'].rank(method='min', ascending = False)

# save the model to disk
filename = 'models/LGBM_models/C_model_10feats.pkl'
joblib.dump(model, filename)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.441 total time=  10.1s
# [CV 2/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 2/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.448 total time=  10.1s
# [CV 3/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 3/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.503 total time=  10.4s
# [CV 4/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 4/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.424 total time=  10.1s
# [CV 5/5; 1/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 5/5; 1/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7.358 total time=  10.4s
# [CV 1/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 1/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.089 total time=  15.0s
# [CV 2/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 2/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.107 total time=  15.1s
# [CV 3/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 3/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.150 total time=  15.2s
# [CV 4/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.097 total time=  15.5s
# [CV 5/5; 2/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 2/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.068 total time=  15.1s
# [CV 1/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.814 total time=  20.6s
# [CV 2/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.829 total time=  20.7s
# [CV 3/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.857 total time=  20.6s
# [CV 4/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.826 total time=  20.6s
# [CV 5/5; 3/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 3/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=20, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-6.805 total time=  20.6s
# [CV 1/5; 4/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1
# [CV 1/5; 4/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=-1, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=62, random_state=1;, score=-7
5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.394 total time=  15.1s
# [CV 4/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 4/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.322 total time=  15.4s
# [CV 5/5; 17/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1
# [CV 5/5; 17/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=93, random_state=1;, score=-7.264 total time=  15.3s
# [CV 1/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 1/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.064 total time=  20.2s
# [CV 2/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 2/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.086 total time=  20.6s
# [CV 3/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 3/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.149 total time=  20.8s
# [CV 4/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 4/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.096 total time=  20.3s
# [CV 5/5; 18/18] START device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1
# [CV 5/5; 18/18] END device=gpu, learning_rate=0.1, max_bin=63, max_depth=40, min_child_samples=80, n_estimators=1000, n_jobs=-1, num_leaves=127, random_state=1;, score=-7.035 total time=  20.0s
# best params
# {'device': 'gpu', 'learning_rate': 0.1, 'max_bin': 63, 'max_depth': 40, 'min_child_samples': 20, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 127, 'random_state': 1} -6.824623280207651
#  MAE: 6.611609
# T10 features ['Blocks', 'def_c_ORBRank3', 'Assists_pg', 'OffensiveRebounds_pg', 'def_TwoPointAttempts_pg', 'BPM_pg3', 'TrueShootingPercentage_pg', 'c_PFRank3', 'def_c_PFRank3', 'def_TS%_pg3']
# ['models/LGBM_models/C_model_10feats.pkl']

# %%
# write predictions to csv
pdf.to_csv(etl_dir + 'c_predictions_lgbm_50_30_20_15_10.csv')

# create df to summarize results

feature_sets = ['all', '50', '30', '20', '10']

mae_values = [
    "{:.2f}".format(mean_absolute_error(Y_test, preds_all)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds50)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds30)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds20)),
    "{:.2f}".format(mean_absolute_error(Y_test, preds10))
]

results_df = pd.DataFrame({'Features' : feature_sets, 'MAE' : mae_values})

results_df.style.hide_index()
display(results_df)
# Out:
#   Features   MAE
# 0      all  5.26
# 1       50  5.59
# 2       30  5.81
# 3       20  6.14
# 4       10  6.61

# %%
pdf.sort_values(by = ['Date', 'Act_C_DKPts'], ascending = [True, False]).head(n=20)
# Out:
#        Season  Date Team Defense             Player  Act_C_DKPtsRank  \
# 7237     2012     0  CLE     WAS   Anderson Varejão              1.0
# 12620    2012     0  MIA     BOS         Chris Bosh              4.0
# 5872     2012     0  LAL     DAL      Dwight Howard              6.0
# 2108     2012     0  CLE     WAS   Tristan Thompson              7.0
# 3036     2012     0  BOS     MIA      Kevin Garnett             12.0
# 9714     2012     0  DAL     LAL     Brandan Wright             14.0
# 4850     2012     0  WAS     CLE        Earl Barron             16.0
# 10426    2012     1  SAS     NOH         Tim Duncan              5.0
# 14431    2012     1  IND     TOR         David West             19.0
# 15103    2012     1  SAC     CHI   DeMarcus Cousins             19.0
# 3461     2012     1  POR     LAL  LaMarcus Aldridge             26.0
# 3510     2012     1  NOH     SAS        Robin Lopez             37.0
# 7913     2012     1  LAC     MEM      Blake Griffin             49.0
# 15898    2012     1  LAC     MEM      Blake Griffin             49.0
# 12337    2012     1  GSW     PHO       Festus Ezeli             55.0
# 2072     2012     1  DAL     UTA      Bernard James             56.0
# 7307     2012     1  DET     HOU     Andre Drummond             65.0
# 11145    2012     1  LAC     MEM       Ryan Hollins             70.0
# 7470     2012     2  SAS     OKC         Tim Duncan              1.0
# 13120    2012     2  SAS     OKC       DeJuan Blair              9.0
#
#        Act_C_DKPts  Pred_C_DKPts_all  PredictedallRank  Pred_C_DKPts_50  \
# 7237          55.1         53.685842               1.0        53.431763
# 12620         40.5         37.982321               2.0        37.166619
# 5872          34.0         23.503385               7.0        19.091871
# 2108          32.5         31.360322               3.0        29.784760
# 3036          27.4         27.205698               4.0        26.484996
# 9714          26.0         25.661536               5.0        25.013578
# 4850          23.6         24.136016               6.0        21.427778
# 10426         45.7         43.058412               1.0        43.110357
# 14431         31.9         29.902080               2.0        30.344086
# 15103         31.9         23.201327               8.0        19.990157
# 3461          27.6         27.209759               5.0        27.778487
# 3510          24.3         17.286567              11.0        24.452680
# 7913          21.4         29.179044               3.0        22.885161
# 15898         21.4         29.179044               3.0        22.885161
# 12337         18.0         25.060831               7.0        22.971350
# 2072          17.2         22.306879               9.0        31.100008
# 7307          11.4         18.291480              10.0        23.614364
# 11145          7.6         26.636678               6.0        28.752023
# 7470          40.1         40.232031               1.0        38.575906
# 13120          7.3          8.505024               4.0         7.562386
#
#        Predicted50Rank  Pred_C_DKPts_30  Predicted30Rank  Pred_C_DKPts_20  \
# 7237               1.0        51.620945              1.0        48.961527
# 12620              2.0        37.122666              2.0        37.427944
# 5872               7.0        19.490786              7.0        16.651493
# 2108               3.0        32.670381              3.0        30.742896
# 3036               4.0        27.208818              4.0        25.697883
# 9714               5.0        25.944744              5.0        24.240652
# 4850               6.0        22.530366              6.0        19.452227
# 10426              1.0        42.971058              1.0        43.520786
# 14431              3.0        28.544788              6.0        29.491910
# 15103             11.0        18.387854             10.0        22.975164
# 3461               5.0        28.674737              5.0        28.741454
# 3510               6.0        28.304090              7.0        25.105372
# 7913               9.0        30.032192              3.0        24.159798
# 15898              9.0        30.032192              3.0        24.159798
# 12337              8.0        20.168593              9.0        21.702360
# 2072               2.0        32.933315              2.0        27.401391
# 7307               7.0        20.429514              8.0        20.343013
# 11145              4.0        17.991696             11.0        19.316109
# 7470               1.0        38.626840              1.0        36.740663
# 13120              4.0         6.847913              4.0         8.557962
#
#        Predicted20Rank  Pred_C_DKPts_10  Predicted10Rank
# 7237               1.0        46.134551              1.0
# 12620              2.0        32.526078              3.0
# 5872               7.0        32.141061              4.0
# 2108               3.0        36.684435              2.0
# 3036               4.0        31.677585              5.0
# 9714               5.0        29.652342              6.0
# 4850               6.0        19.805073              7.0
# 10426              1.0        39.329407              1.0
# 14431              2.0        28.799825              4.0
# 15103              8.0        28.197680              5.0
# 3461               3.0        29.378252              3.0
# 3510               5.0        22.000038             10.0
# 7913               6.0        26.652389              6.0
# 15898              6.0        26.652389              6.0
# 12337              9.0        24.675310              9.0
# 2072               4.0        36.049159              2.0
# 7307              10.0        25.946521              8.0
# 11145             11.0        12.367830             11.0
# 7470               1.0        38.826551              1.0
# 13120              4.0         7.982809              4.0
